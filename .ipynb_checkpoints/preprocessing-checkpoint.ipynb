# %%
import numpy as np
import os
import nrrd
import h5py
import pandas
import json
from data import *
# Out:
# /home/davech2y/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# database_root = "/mnt/raid/davech2y/ShapeNetCore_vol/"
# database_name = "nrrd_256_filter_div_32_solid.hdf5"
# database = h5py.File(os.path.join(database_root, database_name), "w")

# shapenet_root = "/mnt/raid/davech2y/ShapeNetCore_vol/nrrd_256_filter_div_32_solid/"
# shapenet_csv = pandas.read_csv("captions.tablechair.csv")
# shapenet_shapepath = [
#     os.path.join(shapenet_root, model_name, model_name + '.nrrd') for model_name in shapenet_csv.modelId.values.tolist()
# ]
# shapenet_size = len(shapenet_shapepath)
# shapenet_shape = [3, 32, 32, 32]
# shapenet_shape_flat = np.prod(shapenet_shape)

# shapenet_dataset = database.create_dataset("shapes", (shapenet_size, shapenet_shape_flat), dtype="float")

# for i, shapepath in enumerate(shapenet_shapepath):
#     if i % 100 == 0: 
#         print("preprocessed and stored: ", i)
#     shape, _ = nrrd.read(shapepath)
#     shape = np.reshape(shape[:3], (-1))
#     shape = (shape - np.min(shape)) / (np.max(shape) - np.min(shape))
#     shapenet_dataset[i] = shape

# %%
coco_root = "/mnt/raid/davech2y/COCO_2014/"
coco_train = os.path.join(coco_root, "train2014")
coco_valid = os.path.join(coco_root, "valid2014")
coco_test = os.path.join(coco_root, "test2014")
coco_train_cap = os.path.join(coco_root, "annotations", "captions_train2014.json")
coco_valid_cap = os.path.join(coco_root, "annotations", "captions_val2014.json")

# %%
coco_valid = COCO(pandas.read_csv(os.path.join(coco_root, "preprocessed", "coco_val2014.caption.csv")), 100)

# %%
pandas.read_csv(os.path.join(coco_root, "preprocessed", "coco_val2014.caption.csv")).sample(frac=1).reset_index(drop=True)
# Out:
#         image_id                                            caption  \
# 0         338417  A crowd of people standing at a social get tog...
# 1         206356  A baseball player is holding a bat in preparat...
# 2          58344  there is a large building that has two clocks ...
# 3         340884       a elephant walking in a dusty and rocky area
# 4         293057  A person on a snowboard jumping off a pile of ...
# 5         173772        Group of people playing soccer in the snow.
# 6         363039    this is a bird flying in the sky with its wings
# 7         231097  A plate is left sitting half eaten with mostly...
# 8         388225       A man and a woman enjoying the Nintendo Wii.
# 9         285645     a person riding skis holding on to a parachute
# 10        525777               A man in a suit sits alone on a bus.
# 11        434412             a stuffed animal on a number of boxes
# 12        168200    View of overhead jet plane on landing approach.
# 13        424551      A skier is standing at the top of ski slope.
# 14        365387  View of a public men's' room with a  cot on th...
# 15        397742        A piece of bread has eggs on it on a plate.
# 16        364343          A fruit salad piled on top of flat bread.
# 17        463066      A cat perched on top of  a white toilet seat.
# 18         37456         A man and woman standing in a living room.
# 19        279145  A white cat sitting before a bench surrounded ...
# 20        353108          A group of sheep with tags on there ears.
# 21        549351  A pipe chimney on the roof and a table with ch...
# 22        117563  Two men standing in a living room holding game...
# 23        137501  A group of people on skies with contestant num...
# 24        256250       Two giraffes that are standing in the grass.
# 25         20837  Two adult zebras and a baby zebra in a meadow ...
# 26        549230  A group of people spend time together in a liv...
# 27        370401  View from behind of a bench with a woman sitti...
# 28        379022       a blue boat and its reflection on some water
# 29         84749        A cat sits in the shadow of a blue doorway.
# ...          ...                                                ...
# 202624     80057          A brown teddy bear sits by a child's toy.
# 202625    159627   A white bus traveling down a road next to a car.
# 202626    578821          A pizza pie sitting on a board on a table
# 202627    126634  A group of young skiers pose in a line on a sn...
# 202628    262738      Two people are playing a video game together.
# 202629    280424  little zebras standing with a bigger one by a ...
# 202630    257660  A toilet with a light blue cover next to a sho...
# 202631    348795      Man sit on a icy bench with skis on his feet.
# 202632    499631   A large group of stuffed bears sitting together.
# 202633     24869              A young man in a tie with wavy bangs.
# 202634    263177  A glass front high rise is loaded with billboa...
# 202635    110389                A train that is sitting on a track.
# 202636    179487  A woman hitting a tennis ball with her knees b...
# 202637    558587  a woman rides a pink motorcycle that has bull ...
# 202638    444493  a bus pulling up in front of a bus pick up spots
# 202639    253408  Two women in a bar look up and smile to the ca...
# 202640    250540         Men in hard hats are on small motorcycles.
# 202641    474388  A group o sheep with blue markings in a grassy...
# 202642    507833  A city bus has a large mural of a girl on the ...
# 202643    251211    A train traveling down tracks through a forest.
# 202644    531784  A laptop computer sitting on top of a set of t...
# 202645     29080  A man sitting on a boat anchor looking at his ...
# 202646    539678                 a bear is sitting in a green field
# 202647    210501  A train moving along the tracks with empty carts.
# 202648    269867  The tall green vase is  in perfect contrast to...
# 202649    187852  close up of a person with a white hat operatin...
# 202650    327665  A woman stands next to a stop sign that featur...
# 202651    348379     A number of people standing around with signs.
# 202652    459440  There is a paper with a drawing an a nokia pho...
# 202653    265872  A black motorcycle is perched up on a grassy h...
#
#                             file_name
# 0       COCO_val2014_000000338417.jpg
# 1       COCO_val2014_000000206356.jpg
# 2       COCO_val2014_000000058344.jpg
# 3       COCO_val2014_000000340884.jpg
# 4       COCO_val2014_000000293057.jpg
# 5       COCO_val2014_000000173772.jpg
# 6       COCO_val2014_000000363039.jpg
# 7       COCO_val2014_000000231097.jpg
# 8       COCO_val2014_000000388225.jpg
# 9       COCO_val2014_000000285645.jpg
# 10      COCO_val2014_000000525777.jpg
# 11      COCO_val2014_000000434412.jpg
# 12      COCO_val2014_000000168200.jpg
# 13      COCO_val2014_000000424551.jpg
# 14      COCO_val2014_000000365387.jpg
# 15      COCO_val2014_000000397742.jpg
# 16      COCO_val2014_000000364343.jpg
# 17      COCO_val2014_000000463066.jpg
# 18      COCO_val2014_000000037456.jpg
# 19      COCO_val2014_000000279145.jpg
# 20      COCO_val2014_000000353108.jpg
# 21      COCO_val2014_000000549351.jpg
# 22      COCO_val2014_000000117563.jpg
# 23      COCO_val2014_000000137501.jpg
# 24      COCO_val2014_000000256250.jpg
# 25      COCO_val2014_000000020837.jpg
# 26      COCO_val2014_000000549230.jpg
# 27      COCO_val2014_000000370401.jpg
# 28      COCO_val2014_000000379022.jpg
# 29      COCO_val2014_000000084749.jpg
# ...                               ...
# 202624  COCO_val2014_000000080057.jpg
# 202625  COCO_val2014_000000159627.jpg
# 202626  COCO_val2014_000000578821.jpg
# 202627  COCO_val2014_000000126634.jpg
# 202628  COCO_val2014_000000262738.jpg
# 202629  COCO_val2014_000000280424.jpg
# 202630  COCO_val2014_000000257660.jpg
# 202631  COCO_val2014_000000348795.jpg
# 202632  COCO_val2014_000000499631.jpg
# 202633  COCO_val2014_000000024869.jpg
# 202634  COCO_val2014_000000263177.jpg
# 202635  COCO_val2014_000000110389.jpg
# 202636  COCO_val2014_000000179487.jpg
# 202637  COCO_val2014_000000558587.jpg
# 202638  COCO_val2014_000000444493.jpg
# 202639  COCO_val2014_000000253408.jpg
# 202640  COCO_val2014_000000250540.jpg
# 202641  COCO_val2014_000000474388.jpg
# 202642  COCO_val2014_000000507833.jpg
# 202643  COCO_val2014_000000251211.jpg
# 202644  COCO_val2014_000000531784.jpg
# 202645  COCO_val2014_000000029080.jpg
# 202646  COCO_val2014_000000539678.jpg
# 202647  COCO_val2014_000000210501.jpg
# 202648  COCO_val2014_000000269867.jpg
# 202649  COCO_val2014_000000187852.jpg
# 202650  COCO_val2014_000000327665.jpg
# 202651  COCO_val2014_000000348379.jpg
# 202652  COCO_val2014_000000459440.jpg
# 202653  COCO_val2014_000000265872.jpg
#
# [202654 rows x 3 columns]

# %%
coco_valid_ds = COCOCaptionDataset(
    coco_root, 
    coco_valid.transformed_csv,
    os.path.join(coco_root, "preprocessed", "coco_val2014.hdf5")
)

# %%
len(train)
# Out:
# 29

# %%
import matplotlib.pyplot as plt

root = "/home/davech2y/3d_captioning/logs/bad/"
fig = plt.gcf()
fig.set_size_inches(16,32)
fig.set_facecolor("white")
for i in range(1, 5):
    temp = json.load(open(os.path.join(root, "run_coco_vgg16_bn_attention_trs-1_vs5000_ts0_e30_lr0.000100_wd0.000000_bs24_vocal5001_BLEU_BLEU-{}_train_bleu_{}-tag-BLEU_BLEU-{}.json".format(i, i, i))))
    train = [temp[i][2] for i in range(len(temp))]
    temp = json.load(open(os.path.join(root, "run_coco_vgg16_bn_attention_trs-1_vs5000_ts0_e30_lr0.000100_wd0.000000_bs24_vocal5001_BLEU_BLEU-{}_valid_bleu_{}-tag-BLEU_BLEU-{}.json".format(i, i, i))))
    valid = [temp[i][2] for i in range(len(temp))]
    plt.subplot(4, 1, i)
    plt.plot(range(0, 29), train, "C3", label="train_bleu")
    plt.plot(range(0, 29), valid, "C4", label="valid_bleu")
    plt.xlabel('epoch')
    plt.ylabel('BLEU-{}'.format(i))
    plt.xticks(range(0, 29))
    plt.legend()
plt.show()
