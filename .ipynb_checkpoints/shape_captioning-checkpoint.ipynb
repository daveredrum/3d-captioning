# %% [markdown]
# # 3D Shape/Scene Captioning
# ## 0. settings

# %%
import pandas 
import numpy as np
import os
import re
import operator
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from data import *
from constants import *
from models import *
from solver import *
import matplotlib.pyplot as plt

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="0"
os.environ["CUDA_LAUNCH_BLOCKING"]="1"
root = "/mnt/raid/davech2y/ShapeNetCore_vol/nrrd_256_filter_div_128/"
total_size = [4, 8, 16, 32]
train_size = [math.ceil(size / 2) for size in total_size]

# %%
train_captions = []
valid_captions = []
vocal_sizes = []
dict_w2is = []
dict_i2ws = []
corpa = []
for i, size in enumerate(total_size):
    captions = pandas.read_csv("captions.tablechair.csv").iloc[:size]
    captions = Caption(captions)
    captions.preprocess()
    captions.tranform()
    train_captions.append(captions.tranformed_csv.iloc[:math.ceil(size / 2)])
    valid_captions.append(captions.tranformed_csv.iloc[math.ceil(size / 2):size].reset_index(drop=True))
    vocal_sizes.append(captions.dict_word2idx.__len__())
    dict_w2is.append(captions.dict_word2idx)
    dict_i2ws.append(captions.dict_idx2word)
    corpus.append(captions.corpus)
    print("[set %d]: total_size: %d, train_size: %d, valid_size: %d, vocal_size: %d" 
          % (i+1, size, train_captions[-1].id.count(), valid_captions[-1].id.count(), captions.dict_word2idx.__len__()))
# Out:
# [set 1]: total_size: 4, train_size: 2, valid_size: 2, vocal_size: 49
# [set 2]: total_size: 8, train_size: 4, valid_size: 4, vocal_size: 82
# [set 3]: total_size: 16, train_size: 8, valid_size: 8, vocal_size: 111
# [set 4]: total_size: 32, train_size: 16, valid_size: 16, vocal_size: 158

# %% [markdown]
# ## 1. 2D encoder-decoder for image captioning

# %%
###################################################################
#                                                                 #
#                                                                 #
#                   training for encoder-decoder                  #
#                                                                 #
#                                                                 #
###################################################################

train_log = []
models = []
for train_caption, valid_caption, vocal_size, dictionary in zip(train_captions, valid_captions, vocal_sizes, dict_i2ws):
    print("[Info] train_size: %d, valid_size: %d, vocal_size: %d\n" % 
          (train_caption.id.count(), valid_caption.id.count(), vocal_size))
    
    # prepare the dataloader
    transform = transforms.Compose([transforms.Resize(IMAGE_SIZE), transforms.ToTensor()])
    train_ds = ImageCaptionDataset(root, train_caption, transform)
    train_dl = DataLoader(train_ds, batch_size=50)
    valid_ds = ImageCaptionDataset(root, valid_caption, transform)
    valid_dl = DataLoader(valid_ds, batch_size=50)
    dataloader = {
        'train': train_dl,
        'valid': valid_dl
    }

    # # load the pretrained encoder
    # encoder = torch.load("data/encoder.pth").cuda()

    # initialize the encoder
    encoder = Encoder2D().cuda()

    # define the decoder
    input_size = vocal_size + 1
    hidden_size = 512
    num_layer = 2
    decoder = Decoder(input_size, hidden_size, num_layer).cuda()

    # prepare the training parameters
    # optimizer = optim.Adam(list(decoder.parameters()) + list(encoder.fc_layer.parameters()), lr=0.001)
    params = list(decoder.parameters()) + list(encoder.conv_layer.parameters()) + list(encoder.fc_layer.parameters())
    optimizer = optim.Adam(params, lr=0.0001)
    criterion = nn.CrossEntropyLoss()
    # criterion = nn.NLLLoss()
    epoch = 100
    verbose = 10

    # training
    encoder_decoder_solver = EncoderDecoderSolver(optimizer, criterion, model_type="2d")
    encoder_decoder_solver.train(encoder, decoder, dataloader, dictionary, epoch, verbose)
    
    # save
    train_log.append(encoder_decoder_solver.log)
    models.append((encoder, decoder))
    torch.save(encoder, "data/encoder_%s_ts%d_e%d_lr%f_bs%d_vocal%d.pth"  % ("2d", train_caption.id.count() + valid_caption.id.count(), epoch, 0.0001, 50, input_size))
    torch.save(decoder, "data/decoder_%s_ts%d_e%d_lr%f_bs%d_vocal%d.pth"  % ("2d", train_caption.id.count() + valid_caption.id.count(), epoch, 0.0001, 50, input_size))
    print()
# Out:
# [Info] train_size: 2, valid_size: 2, vocal_size: 49
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-63cda6fd581c> in <module>()
#      47     # training
#      48     encoder_decoder_solver = EncoderDecoderSolver(optimizer, criterion, model_type="2d")
# ---> 49     encoder_decoder_solver.train(encoder, decoder, dataloader, dictionary, epoch, verbose)
#      50
#      51     # save
#
# ~/3d_captioning/solver.py in train(self, encoder, decoder, dataloader, dictionary, epoch, verbose)
#     171                 else:
#     172                     encoder.train()
# --> 173                 for visuals, captions, cap_lengths in dataloader[phase]:
#     174                     # visuals must be tensor
#     175                     caption_inputs = torch.cat([item.view(1, -1) for item in captions]).transpose(1, 0)[:, :cap_lengths[0]-1]
#
# ...

# %%
from nltk.translate.bleu_score import sentence_bleu

for model_ids, visuals, captions, cap_lengths in dataloader["train"]:
    # visuals must be tensor
    caption_inputs = torch.cat([item.view(1, -1) for item in captions]).transpose(1, 0)[:, :cap_lengths[0]-1]
    caption_targets = torch.cat([item.view(1, -1) for item in captions]).transpose(1, 0)[:, :cap_lengths[0]]
    blue_ref = caption_targets
    visual_inputs = Variable(visuals).cuda()
    caption_inputs = Variable(caption_inputs).cuda()
    caption_targets = Variable(caption_targets).cuda()
    caption_targets = pack_padded_sequence(caption_targets, cap_lengths, batch_first=True)[0]
    cap_lengths = Variable(cap_lengths).cuda()
    visual_contexts = encoder.extract(visual_inputs)
    outputs, _ = decoder(visual_contexts, caption_inputs, cap_lengths)
    break

# %%
idx = [0] + cap_lengths.tolist()
idx = [0] + [idx[i] + idx[i + 1] for i in range(len(idx)-1)]

# %%
blue_ref.tolist()[1]
# Out:
# [5,
#  3,
#  1,
#  25,
#  26,
#  8,
#  2,
#  3,
#  1,
#  14,
#  27,
#  28,
#  2,
#  29,
#  30,
#  1,
#  31,
#  32,
#  33,
#  34,
#  35,
#  36,
#  3,
#  2,
#  3,
#  1,
#  16,
#  10,
#  11,
#  2,
#  7,
#  0,
#  0]

# %%
idx = cap_lengths.tolist()
[outputs.max(1)[1].tolist()[idx[i]:idx[i + 1]] for i in range(len(idx)+1)]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-75cd47eb7304> in <module>()
#       1 idx = cap_lengths.tolist()
# ----> 2 [outputs.max(1)[1].tolist()[idx[i]:idx[i + 1]] for i in range(len(idx)+1)]
#
# <ipython-input-24-75cd47eb7304> in <listcomp>(.0)
#       1 idx = cap_lengths.tolist()
# ----> 2 [outputs.max(1)[1].tolist()[idx[i]:idx[i + 1]] for i in range(len(idx)+1)]
#
# IndexError: list index out of range

# %%
cap_lengths.tolist()
# Out:
# [36, 33, 31, 27]

# %%
[[item[0][:item[1]] for item in zip(outputs.max(1)[1].tolist(), cap_lengths.tolist())]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-1fc73710c13d> in <module>()
# ----> 1 [[item[0][:item[1]] for item in zip(outputs.max(1)[1].tolist(), cap_lengths.tolist())]]
#
# <ipython-input-13-1fc73710c13d> in <listcomp>(.0)
# ----> 1 [[item[0][:item[1]] for item in zip(outputs.max(1)[1].tolist(), cap_lengths.tolist())]]
#
# TypeError: 'int' object is not subscriptable

# %%
dic = dict_i2ws[2]
sentence_bleu([dic[item] for item in caption_targets.tolist()], [dic[item] for item in outputs.max(1)[1].tolist()])
# Out:
# 0.44544241775243665

# %%
# plot the result
fig = plt.gcf()
fig.set_size_inches(16,8)
for i in range(4):
    plt.subplot(2, 2, i + 1)
    plt.plot(range(epochs), [train_log[i][j]["train_loss"] for j in range(epochs)], label="train_loss")
    plt.plot(range(epochs), [train_log[i][j]["valid_loss"] for j in range(epochs)], label="valid_loss")
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.xticks(range(0, epochs + 1, math.floor(epoch / 10)))
    plt.legend()
plt.show()

# %%
###################################################################
#                                                                 #
#                                                                 #
#       caption generating via encoder-decoder pipeline           #
#                                                                 #
#                                                                 #
###################################################################

# initialize the pipeline
encoder_path = "data/encoder_checkpoint_2d.pth"
decoder_path = "data/decoder_checkpoint_2d.pth"
encoder_decoder = EncoderDecoder2D(encoder_path, decoder_path)

# prepare the dataloader
transform = transforms.Compose([transforms.Resize(IMAGE_SIZE), transforms.ToTensor()])
train_ds = ImageCaptionDataset(root, train_captions[-1], transform)
dataloader = DataLoader(train_ds, batch_size=1, shuffle=False)

# caption images
descriptions = []
images = []
for i, (image_inputs, caps, cap_lengths) in enumerate(dataloader):
    image_inputs = Variable(image_inputs).cuda()
    descriptions += encoder_decoder.generate_text(image_inputs, captions.dict_idx2word, 50)
    images.append(image_inputs)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-794b9e6f42af> in <module>()
#      10 encoder_path = "data/encoder_checkpoint_2d.pth"
#      11 decoder_path = "data/decoder_checkpoint_2d.pth"
# ---> 12 encoder_decoder = EncoderDecoder2D(encoder_path, decoder_path)
#      13
#      14 # prepare the dataloader
#
# ~/3d_captioning/models.py in __init__(self, encoder_path, decoder_path, cuda_flag)
#     124     def __init__(self, encoder_path, decoder_path, cuda_flag=True):
#     125         if cuda_flag:
# --> 126             self.encoder = torch.load(encoder_path).cuda()
#     127             self.decoder = torch.load(decoder_path).cuda()
#     128         else:
#
# ~/anaconda3/lib/python3.6/site-packages/torch/serialization.py in load(f, map_location, pickle_module)
#     301         f = open(f, 'rb')
#     302     try:
# ...

# %%
descriptions
# Out:
# ['<START> classic design with contemporary style glass table . the base is steel coated legs . there is also a storage facility just below the top . the glass is attached through four bolts . <END>',
#  '<START> a simple chair with wooden back rest and seating rest . the whole frame of the chair is powder coated stainless steel . it is brown and grey in colour . <END>',
#  '<START> it is narrow console table . it is made from plywood . its size is quite good to place anything on it . it is grey in colour . <END>',
#  '<START> panel based three cluster workstation having three nos . of semi-circular shaped workstation . it is blue and grey in colour . the base is of three legs <END>',
#  '<START> a double cushion chair . the back rest cushion is larger than the seating rest . it is an arm chair . it is purple in colour . <END>',
#  '<START> it is simple chiar with comfortable back rest and seating rest . the chair is floating between two arches of tough stainless steel legs . <END>',
# ...

# %%
transforms.ToPILImage()(images[0].cpu().view(3, 64, 64))
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F12AC7D1FD0>

# %% [markdown]
# ## 2. 3D encoder-decoder for shape captioning

# %%
###################################################################
#                                                                 #
#                                                                 #
#                   training for encoder-decoder                  #
#                                                                 #
#                                                                 #
###################################################################

train_log = []
models = []
for train_caption, valid_caption, vocal_size in zip(train_captions, valid_captions, vocal_sizes):
    print("[Info] train_size: %d, valid_size: %d, vocal_size: %d" % 
          (train_caption.id.count(), valid_caption.id.count(), vocal_size))
    
    # prepare the dataloader
    train_ds = ShapeCaptionDataset(root, train_caption)
    train_dl = DataLoader(train_ds, batch_size=2)
    valid_ds = ShapeCaptionDataset(root, valid_caption)
    valid_dl = DataLoader(valid_ds, batch_size=2)
    dataloader = {
        'train': train_dl,
        'valid': valid_dl
    }

    # # load the pretrained encoder
    # encoder = torch.load("data/encoder.pth").cuda()

    # initialize the encoder
    encoder = Encoder3D().cuda()

    # define the decoder
    input_size = vocal_size + 1
    hidden_size = 512
    num_layer = 2
    decoder = Decoder(input_size, hidden_size, num_layer).cuda()

    # prepare the training parameters
    # optimizer = optim.Adam(list(decoder.parameters()) + list(encoder.fc_layer.parameters()), lr=0.001)
    params = list(decoder.parameters()) + list(encoder.conv_layer.parameters()) + list(encoder.fc_layer.parameters())
    optimizer = optim.Adam(params, lr=0.0001)
    criterion = nn.CrossEntropyLoss()
    # criterion = nn.NLLLoss()
    epoch = 200
    verbose = 10

    # training
    encoder_decoder_solver = EncoderDecoderSolver(optimizer, criterion, model_type="3d")
    encoder_decoder_solver.train(encoder, decoder, dataloader, epoch, verbose)
    
    # save
    train_log.append(encoder_decoder_solver.log)
    models.append((encoder, decoder))
    print()
# Out:
# [Info] train_size: 2, valid_size: 2, vocal_size: 49
# [epoch 10/200] train_loss: 3.786736, valid_loss: 3.900572, ETA: 3m 51s
# [epoch 20/200] train_loss: 3.548110, valid_loss: 3.857698, ETA: 3m 14s
# [epoch 30/200] train_loss: 3.081443, valid_loss: 3.775027, ETA: 4m 0s
# [epoch 40/200] train_loss: 2.570866, valid_loss: 3.790466, ETA: 3m 30s
# [epoch 50/200] train_loss: 2.048444, valid_loss: 3.874024, ETA: 3m 51s
# [epoch 60/200] train_loss: 1.583063, valid_loss: 4.080707, ETA: 2m 57s
# [epoch 70/200] train_loss: 1.224955, valid_loss: 4.392783, ETA: 3m 6s
# [epoch 80/200] train_loss: 0.959355, valid_loss: 4.691041, ETA: 2m 14s
# [epoch 90/200] train_loss: 0.767147, valid_loss: 4.927208, ETA: 2m 51s
# [epoch 100/200] train_loss: 0.625056, valid_loss: 5.114189, ETA: 2m 8s
# [epoch 110/200] train_loss: 0.518321, valid_loss: 5.220056, ETA: 2m 11s
# [epoch 120/200] train_loss: 0.435352, valid_loss: 5.329604, ETA: 1m 25s
# ...

# %%
# plot the result
fig = plt.gcf()
fig.set_size_inches(16,8)
for i in range(len(train_log)):
    plt.subplot(math.ceil(len(train_log) / 2), 2, i + 1)
    plt.plot(range(epoch), [train_log[i][j]["train_loss"] for j in range(epoch)], label="train_loss")
    plt.plot(range(epoch), [train_log[i][j]["valid_loss"] for j in range(epoch)], label="valid_loss")
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.xticks(range(0, epoch + 1, math.floor(epoch / 10)))
    plt.legend()
plt.show()

# %%
###################################################################
#                                                                 #
#                                                                 #
#       caption generating via encoder-decoder pipeline           #
#                                                                 #
#                                                                 #
###################################################################

# initialize the pipeline
encoder_path = "data/encoder_checkpoint_3d.pth"
decoder_path = "data/decoder_checkpoint_3d.pth"
encoder_decoder = EncoderDecoder3D(encoder_path, decoder_path)

# prepare the dataloader
train_ds = ShapeCaptionDataset(root, train_captions[-1])
dataloader = DataLoader(train_ds, batch_size=1, shuffle=False)

# caption images
descriptions = []
images = []
for i, (image_inputs, caps, cap_lengths) in enumerate(dataloader):
    image_inputs = Variable(image_inputs).cuda()
    descriptions += encoder_decoder.generate_text(image_inputs, captions.dict_idx2word, 50)
    images.append(image_inputs)

# %%
descriptions
# Out:
# ['<START> it is snooker table . it has four big bolt like legs with wheel . it is grey in colour . <END>',
#  '<START> a grey sofa seat with leather seat and wire rack type of material <END>',
#  '<START> it is narrow console table . it is made from plywood . its size is quite good to place anything on it . it is grey in colour . <END>',
#  '<START> a grey sofa seat with leather seat and wire rack type of material <END>',
#  '<START> a stylish brown coloured chair , provided with perfect supporings at the bottom . <END>',
#  '<START> the table is round and has 3 legs . the table is rotating <END>',
#  '<START> a black stylish table with round design provided at the centre of the table . <END>',
#  '<START> a stylish brown coloured chair , provided with perfect supporings at the bottom . <END>',
#  '<START> a light green coloured chair , useful for office purposes , provided with perfect supportings . <END>',
# ...
