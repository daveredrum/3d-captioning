# %% [markdown]
# # 3D Shape/Scene Captioning
# ## 0. settings

# %%
import pandas 
import numpy as np
import os
import re
import operator
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from data import *
from constants import *
from models import *
from solver import *
import matplotlib.pyplot as plt

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="1"
os.environ["CUDA_LAUNCH_BLOCKING"]="1"
root = "/mnt/raid/davech2y/ShapeNetCore_vol/nrrd_256_filter_div_128/"
sizes = [
    [16, 2, 2],
    [32, 4, 4]
]

# %%
datasets = []
for i, size in enumerate(sizes):
    datasets.append(Caption(pandas.read_csv("captions.tablechair.csv"), size))
    print("[set %d]: total_size: %d, train_size: %d, valid_size: %d, test_size: %d, vocal_size: %d" 
          % (i+1, 
             datasets[-1].total_size, 
             datasets[-1].train_size, 
             datasets[-1].valid_size,
             datasets[-1].test_size,
             datasets[-1].dict_size))
# Out:
# [set 1]: total_size: 20, train_size: 16, valid_size: 2, test_size: 2, vocal_size: 132
# [set 2]: total_size: 40, train_size: 32, valid_size: 4, test_size: 4, vocal_size: 175

# %% [markdown]
# ## 1. 2D encoder-decoder for image captioning

# %%
###################################################################
#                                                                 #
#                                                                 #
#                   training for encoder-decoder                  #
#                                                                 #
#                                                                 #
###################################################################

train_log = []
models = []
for data in datasets:
    print("[Info] train_size: %d, valid_size: %d, dict_size: %d\n" % 
          (data.train_size, data.valid_size, data.dict_size))
    
    # prepare the dataloader
    transform = transforms.Compose([transforms.Resize(IMAGE_SIZE), transforms.ToTensor()])
    train_ds = ImageCaptionDataset(root, data.transformed_data['train'], transform)
    train_dl = DataLoader(train_ds, batch_size=50)
    valid_ds = ImageCaptionDataset(root, data.transformed_data['valid'], transform)
    valid_dl = DataLoader(valid_ds, batch_size=50)
    dataloader = {
        'train': train_dl,
        'valid': valid_dl
    }

    # # load the pretrained encoder
    # encoder = torch.load("data/encoder.pth").cuda()

    # initialize the encoder
    encoder = Encoder2D().cuda()

    # define the decoder
    input_size = data.dict_size + 1
    hidden_size = 512
    num_layer = 2
    decoder = Decoder(input_size, hidden_size, num_layer).cuda()

    # prepare the training parameters
    # optimizer = optim.Adam(list(decoder.parameters()) + list(encoder.fc_layer.parameters()), lr=0.001)
    params = list(decoder.parameters()) + list(encoder.conv_layer.parameters()) + list(encoder.fc_layer.parameters())
    optimizer = optim.Adam(params, lr=0.0001)
    criterion = nn.CrossEntropyLoss()
    # criterion = nn.NLLLoss()
    epoch = 500
    verbose = 10

    # training
    encoder_decoder_solver = EncoderDecoderSolver(optimizer, criterion, model_type="2d")
    encoder_decoder_solver.train(encoder, decoder, dataloader, data.corpus, data.dict_idx2word, epoch, verbose)
    
    # save
    train_log.append(encoder_decoder_solver.log)
    models.append((encoder, decoder))
    torch.save(encoder, "data/encoder_%s_ts%d_e%d_lr%f_bs%d_vocal%d.pth"  % ("2d", data.train_size + data.valid_size, epoch, 0.0001, 50, input_size))
    torch.save(decoder, "data/decoder_%s_ts%d_e%d_lr%f_bs%d_vocal%d.pth"  % ("2d", data.train_size + data.valid_size, epoch, 0.0001, 50, input_size))
    print()
# Out:
# [Info] train_size: 16, valid_size: 2, dict_size: 132
#
# ---------------------epoch 10/500----------------------
# [train] train_loss: 4.805148, train_blue: 0.503048
# [valid] valid_loss: 4.785519, valid_blue: 0.555711
# [Info]  forward_per_epoch: 0.007191s
# [Info]  backward_per_epoch: 0.016457s
# [Info]  valid_per_epoch: 0.016699s
# [Info]  time_per_epoch: 0.373309s
# [Info]  ETA: 3m 2s
#
# ---------------------epoch 20/500----------------------
# [train] train_loss: 4.654625, train_blue: 0.564857
# [valid] valid_loss: 4.455422, valid_blue: 0.718608
# [Info]  forward_per_epoch: 0.007161s
# [Info]  backward_per_epoch: 0.016489s
# [Info]  valid_per_epoch: 0.015797s
# [Info]  time_per_epoch: 0.379241s
# [Info]  ETA: 3m 2s
#
# ---------------------epoch 30/500----------------------
# [train] train_loss: 4.252887, train_blue: 0.654665
# [valid] valid_loss: 3.969714, valid_blue: 0.661442
# [Info]  forward_per_epoch: 0.009126s
# [Info]  backward_per_epoch: 0.020784s
# [Info]  valid_per_epoch: 0.016333s
# [Info]  time_per_epoch: 0.394962s
# [Info]  ETA: 3m 5s
#
# ---------------------epoch 40/500----------------------
# [train] train_loss: 3.974806, train_blue: 0.419805
# [valid] valid_loss: 3.969163, valid_blue: 0.555711
# [Info]  forward_per_epoch: 0.007272s
# [Info]  backward_per_epoch: 0.020359s
# [Info]  valid_per_epoch: 0.015819s
# [Info]  time_per_epoch: 0.376441s
# [Info]  ETA: 2m 53s
#
# ---------------------epoch 50/500----------------------
# [train] train_loss: 3.668382, train_blue: 0.390181
# [valid] valid_loss: 4.104174, valid_blue: 0.756939
# [Info]  forward_per_epoch: 0.007142s
# [Info]  backward_per_epoch: 0.016885s
# [Info]  valid_per_epoch: 0.015807s
# [Info]  time_per_epoch: 0.362886s
# [Info]  ETA: 2m 43s
#
# ---------------------epoch 60/500----------------------
# [train] train_loss: 3.324561, train_blue: 0.380448
# [valid] valid_loss: 4.185883, valid_blue: 0.603766
# [Info]  forward_per_epoch: 0.007178s
# [Info]  backward_per_epoch: 0.017379s
# [Info]  valid_per_epoch: 0.015767s
# [Info]  time_per_epoch: 0.384437s
# [Info]  ETA: 2m 49s
#
# ---------------------epoch 70/500----------------------
# [train] train_loss: 2.950543, train_blue: 0.344774
# [valid] valid_loss: 4.261571, valid_blue: 0.555711
# [Info]  forward_per_epoch: 0.007212s
# [Info]  backward_per_epoch: 0.018190s
# [Info]  valid_per_epoch: 0.016373s
# [Info]  time_per_epoch: 0.394297s
# [Info]  ETA: 2m 49s
#
# ---------------------epoch 80/500----------------------
# [train] train_loss: 2.567077, train_blue: 0.368329
# [valid] valid_loss: 4.367539, valid_blue: 0.555711
# [Info]  forward_per_epoch: 0.007282s
# [Info]  backward_per_epoch: 0.016428s
# [Info]  valid_per_epoch: 0.015935s
# [Info]  time_per_epoch: 0.390213s
# [Info]  ETA: 2m 43s
#
# ---------------------epoch 90/500----------------------
# [train] train_loss: 2.203103, train_blue: 0.360748
# [valid] valid_loss: 4.566895, valid_blue: 0.507704
# [Info]  forward_per_epoch: 0.007222s
# [Info]  backward_per_epoch: 0.017099s
# [Info]  valid_per_epoch: 0.015977s
# [Info]  time_per_epoch: 0.381171s
# [Info]  ETA: 2m 36s
#
# ---------------------epoch 100/500----------------------
# [train] train_loss: 1.884123, train_blue: 0.351534
# [valid] valid_loss: 4.786547, valid_blue: 0.530777
# [Info]  forward_per_epoch: 0.007172s
# [Info]  backward_per_epoch: 0.017535s
# [Info]  valid_per_epoch: 0.015859s
# [Info]  time_per_epoch: 0.369262s
# [Info]  ETA: 2m 27s
#
# ---------------------epoch 110/500----------------------
# [train] train_loss: 1.616087, train_blue: 0.397793
# [valid] valid_loss: 4.847087, valid_blue: 0.545055
# [Info]  forward_per_epoch: 0.007121s
# [Info]  backward_per_epoch: 0.016056s
# [Info]  valid_per_epoch: 0.015904s
# [Info]  time_per_epoch: 0.364438s
# [Info]  ETA: 2m 22s
#
# ---------------------epoch 120/500----------------------
# [train] train_loss: 1.392410, train_blue: 0.563223
# [valid] valid_loss: 4.952540, valid_blue: 0.545055
# [Info]  forward_per_epoch: 0.007152s
# [Info]  backward_per_epoch: 0.017209s
# [Info]  valid_per_epoch: 0.016101s
# [Info]  time_per_epoch: 0.369532s
# [Info]  ETA: 2m 20s
#
# ---------------------epoch 130/500----------------------
# [train] train_loss: 1.212917, train_blue: 0.723161
# [valid] valid_loss: 5.049537, valid_blue: 0.545055
# [Info]  forward_per_epoch: 0.008590s
# [Info]  backward_per_epoch: 0.018557s
# [Info]  valid_per_epoch: 0.016019s
# [Info]  time_per_epoch: 0.385204s
# [Info]  ETA: 2m 22s
#
# ---------------------epoch 140/500----------------------
# [train] train_loss: 1.064567, train_blue: 0.811274
# [valid] valid_loss: 5.412015, valid_blue: 0.739222
# [Info]  forward_per_epoch: 0.007164s
# [Info]  backward_per_epoch: 0.015310s
# [Info]  valid_per_epoch: 0.015853s
# [Info]  time_per_epoch: 0.382828s
# [Info]  ETA: 2m 17s
#
# ---------------------epoch 150/500----------------------
# [train] train_loss: 0.942754, train_blue: 0.848238
# [valid] valid_loss: 5.299339, valid_blue: 0.693674
# [Info]  forward_per_epoch: 0.007131s
# [Info]  backward_per_epoch: 0.016365s
# [Info]  valid_per_epoch: 0.016152s
# [Info]  time_per_epoch: 0.370356s
# [Info]  ETA: 2m 9s
#
# ---------------------epoch 160/500----------------------
# [train] train_loss: 0.839499, train_blue: 0.864819
# [valid] valid_loss: 5.468416, valid_blue: 0.693674
# [Info]  forward_per_epoch: 0.007263s
# [Info]  backward_per_epoch: 0.016888s
# [Info]  valid_per_epoch: 0.015978s
# [Info]  time_per_epoch: 0.370263s
# [Info]  ETA: 2m 5s
#
# ---------------------epoch 170/500----------------------
# [train] train_loss: 0.750990, train_blue: 0.880447
# [valid] valid_loss: 5.545500, valid_blue: 0.661442
# [Info]  forward_per_epoch: 0.007146s
# [Info]  backward_per_epoch: 0.016545s
# [Info]  valid_per_epoch: 0.015856s
# [Info]  time_per_epoch: 0.377780s
# [Info]  ETA: 2m 4s
#
# ---------------------epoch 180/500----------------------
# [train] train_loss: 0.673509, train_blue: 0.881833
# [valid] valid_loss: 5.523448, valid_blue: 0.661442
# [Info]  forward_per_epoch: 0.007083s
# [Info]  backward_per_epoch: 0.017045s
# [Info]  valid_per_epoch: 0.015709s
# [Info]  time_per_epoch: 0.378098s
# [Info]  ETA: 2m 0s
#
# ---------------------epoch 190/500----------------------
# [train] train_loss: 0.604152, train_blue: 0.903621
# [valid] valid_loss: 5.589683, valid_blue: 0.661442
# [Info]  forward_per_epoch: 0.007461s
# [Info]  backward_per_epoch: 0.019256s
# [Info]  valid_per_epoch: 0.015897s
# [Info]  time_per_epoch: 0.370397s
# [Info]  ETA: 1m 54s
#
# ---------------------epoch 200/500----------------------
# [train] train_loss: 0.541279, train_blue: 0.930986
# [valid] valid_loss: 5.883262, valid_blue: 0.714288
# [Info]  forward_per_epoch: 0.007541s
# [Info]  backward_per_epoch: 0.016053s
# [Info]  valid_per_epoch: 0.016365s
# [Info]  time_per_epoch: 0.383518s
# [Info]  ETA: 1m 55s
#
# ---------------------epoch 210/500----------------------
# [train] train_loss: 0.484297, train_blue: 0.940760
# [valid] valid_loss: 5.941629, valid_blue: 0.714288
# [Info]  forward_per_epoch: 0.009214s
# [Info]  backward_per_epoch: 0.019271s
# [Info]  valid_per_epoch: 0.015787s
# [Info]  time_per_epoch: 0.418557s
# [Info]  ETA: 2m 1s
#
# ---------------------epoch 220/500----------------------
# [train] train_loss: 0.433156, train_blue: 0.970159
# [valid] valid_loss: 5.977003, valid_blue: 0.693674
# [Info]  forward_per_epoch: 0.007133s
# [Info]  backward_per_epoch: 0.017791s
# [Info]  valid_per_epoch: 0.015846s
# [Info]  time_per_epoch: 0.372945s
# [Info]  ETA: 1m 44s
#
# ---------------------epoch 230/500----------------------
# [train] train_loss: 0.388418, train_blue: 0.979703
# [valid] valid_loss: 6.512067, valid_blue: 0.507704
# [Info]  forward_per_epoch: 0.007118s
# [Info]  backward_per_epoch: 0.017521s
# [Info]  valid_per_epoch: 0.015829s
# [Info]  time_per_epoch: 0.365461s
# [Info]  ETA: 1m 38s
#
# ---------------------epoch 240/500----------------------
# [train] train_loss: 0.350241, train_blue: 0.979703
# [valid] valid_loss: 6.593001, valid_blue: 0.507704
# [Info]  forward_per_epoch: 0.007124s
# [Info]  backward_per_epoch: 0.018549s
# [Info]  valid_per_epoch: 0.016130s
# [Info]  time_per_epoch: 0.376305s
# [Info]  ETA: 1m 37s
#
# ---------------------epoch 250/500----------------------
# [train] train_loss: 0.318302, train_blue: 0.979703
# [valid] valid_loss: 6.004629, valid_blue: 0.530777
# [Info]  forward_per_epoch: 0.007112s
# [Info]  backward_per_epoch: 0.021243s
# [Info]  valid_per_epoch: 0.015844s
# [Info]  time_per_epoch: 0.396329s
# [Info]  ETA: 1m 39s
#
# ---------------------epoch 260/500----------------------
# [train] train_loss: 0.291648, train_blue: 0.979703
# [valid] valid_loss: 6.063634, valid_blue: 0.530777
# [Info]  forward_per_epoch: 0.007176s
# [Info]  backward_per_epoch: 0.017169s
# [Info]  valid_per_epoch: 0.015778s
# [Info]  time_per_epoch: 0.370071s
# [Info]  ETA: 1m 28s
# ---------------------epoch 270/500----------------------
# [train] train_loss: 0.269231, train_blue: 0.981899
# [valid] valid_loss: 6.123923, valid_blue: 0.530777
# [Info]  forward_per_epoch: 0.007344s
# [Info]  backward_per_epoch: 0.018368s
# [Info]  valid_per_epoch: 0.015940s
# [Info]  time_per_epoch: 0.367223s
# [Info]  ETA: 1m 24s
#
# ---------------------epoch 280/500----------------------
# [train] train_loss: 0.250174, train_blue: 0.980042
# [valid] valid_loss: 6.178199, valid_blue: 0.530777
# [Info]  forward_per_epoch: 0.007168s
# [Info]  backward_per_epoch: 0.020430s
# [Info]  valid_per_epoch: 0.015936s
# [Info]  time_per_epoch: 0.369087s
# [Info]  ETA: 1m 21s
#
# ---------------------epoch 290/500----------------------
# [train] train_loss: 0.233785, train_blue: 0.980470
# [valid] valid_loss: 6.228213, valid_blue: 0.530777
# [Info]  forward_per_epoch: 0.007175s
# [Info]  backward_per_epoch: 0.017423s
# [Info]  valid_per_epoch: 0.015767s
# [Info]  time_per_epoch: 0.386400s
# [Info]  ETA: 1m 21s
#
# ---------------------epoch 300/500----------------------
# [train] train_loss: 0.219533, train_blue: 0.980470
# [valid] valid_loss: 6.274979, valid_blue: 0.530777
# [Info]  forward_per_epoch: 0.007146s
# [Info]  backward_per_epoch: 0.016672s
# [Info]  valid_per_epoch: 0.020816s
# [Info]  time_per_epoch: 0.382853s
# [Info]  ETA: 1m 16s
#
# ---------------------epoch 310/500----------------------
# [train] train_loss: 0.207006, train_blue: 0.983669
# [valid] valid_loss: 6.317717, valid_blue: 0.530777
# [Info]  forward_per_epoch: 0.007131s
# [Info]  backward_per_epoch: 0.017373s
# [Info]  valid_per_epoch: 0.016071s
# [Info]  time_per_epoch: 0.369060s
# [Info]  ETA: 1m 10s
#
# ---------------------epoch 320/500----------------------
# [train] train_loss: 0.195898, train_blue: 0.983669
# [valid] valid_loss: 6.357481, valid_blue: 0.530777
# [Info]  forward_per_epoch: 0.008590s
# [Info]  backward_per_epoch: 0.017788s
# [Info]  valid_per_epoch: 0.016079s
# [Info]  time_per_epoch: 0.383371s
# [Info]  ETA: 1m 9s
#
# ---------------------epoch 330/500----------------------
# [train] train_loss: 0.185961, train_blue: 0.987723
# [valid] valid_loss: 6.395911, valid_blue: 0.530777
# [Info]  forward_per_epoch: 0.007204s
# [Info]  backward_per_epoch: 0.017254s
# [Info]  valid_per_epoch: 0.016277s
# [Info]  time_per_epoch: 0.368972s
# [Info]  ETA: 1m 2s
#
# ---------------------epoch 340/500----------------------
# [train] train_loss: 0.176994, train_blue: 0.991777
# [valid] valid_loss: 6.432431, valid_blue: 0.530777
# [Info]  forward_per_epoch: 0.008269s
# [Info]  backward_per_epoch: 0.016507s
# [Info]  valid_per_epoch: 0.016135s
# [Info]  time_per_epoch: 0.370231s
# [Info]  ETA: 0m 59s
#
# ---------------------epoch 350/500----------------------
# [train] train_loss: 0.168831, train_blue: 0.991777
# [valid] valid_loss: 6.464818, valid_blue: 0.530777
# [Info]  forward_per_epoch: 0.007179s
# [Info]  backward_per_epoch: 0.016508s
# [Info]  valid_per_epoch: 0.016034s
# [Info]  time_per_epoch: 0.371732s
# [Info]  ETA: 0m 55s
#
# ---------------------epoch 360/500----------------------
# [train] train_loss: 0.161308, train_blue: 0.991777
# [valid] valid_loss: 6.491364, valid_blue: 0.530777
# [Info]  forward_per_epoch: 0.007249s
# [Info]  backward_per_epoch: 0.016594s
# [Info]  valid_per_epoch: 0.016093s
# [Info]  time_per_epoch: 0.373622s
# [Info]  ETA: 0m 52s
#
# ---------------------epoch 370/500----------------------
# [train] train_loss: 0.153533, train_blue: 0.991777
# [valid] valid_loss: 6.509096, valid_blue: 0.530777
# [Info]  forward_per_epoch: 0.007164s
# [Info]  backward_per_epoch: 0.014719s
# [Info]  valid_per_epoch: 0.015680s
# [Info]  time_per_epoch: 0.355705s
# [Info]  ETA: 0m 46s
#
# ---------------------epoch 380/500----------------------
# [train] train_loss: 0.139590, train_blue: 0.996440
# [valid] valid_loss: 6.459029, valid_blue: 0.530777
# [Info]  forward_per_epoch: 0.007337s
# [Info]  backward_per_epoch: 0.017602s
# [Info]  valid_per_epoch: 0.016540s
# [Info]  time_per_epoch: 0.371436s
# [Info]  ETA: 0m 44s
#
# ---------------------epoch 390/500----------------------
# [train] train_loss: 0.132199, train_blue: 0.996440
# [valid] valid_loss: 6.483031, valid_blue: 0.530777
# [Info]  forward_per_epoch: 0.007171s
# [Info]  backward_per_epoch: 0.017992s
# [Info]  valid_per_epoch: 0.016584s
# [Info]  time_per_epoch: 0.371191s
# [Info]  ETA: 0m 40s
#
# ---------------------epoch 400/500----------------------
# [train] train_loss: 0.125944, train_blue: 0.996440
# [valid] valid_loss: 6.509833, valid_blue: 0.530777
# [Info]  forward_per_epoch: 0.007153s
# [Info]  backward_per_epoch: 0.017376s
# [Info]  valid_per_epoch: 0.016121s
# [Info]  time_per_epoch: 0.371916s
# [Info]  ETA: 0m 37s
#
# ---------------------epoch 410/500----------------------
# [train] train_loss: 0.120286, train_blue: 0.996440
# [valid] valid_loss: 6.689293, valid_blue: 0.739222
# [Info]  forward_per_epoch: 0.007161s
# [Info]  backward_per_epoch: 0.018423s
# [Info]  valid_per_epoch: 0.015763s
# [Info]  time_per_epoch: 0.375734s
# [Info]  ETA: 0m 33s
#
# ---------------------epoch 420/500----------------------
# [train] train_loss: 0.114968, train_blue: 0.996440
# [valid] valid_loss: 6.711298, valid_blue: 0.739222
# [Info]  forward_per_epoch: 0.007234s
# [Info]  backward_per_epoch: 0.019172s
# [Info]  valid_per_epoch: 0.015823s
# [Info]  time_per_epoch: 0.385231s
# [Info]  ETA: 0m 30s
#
# ---------------------epoch 430/500----------------------
# [train] train_loss: 0.109826, train_blue: 0.996440
# [valid] valid_loss: 6.738419, valid_blue: 0.739222
# [Info]  forward_per_epoch: 0.007164s
# [Info]  backward_per_epoch: 0.017479s
# [Info]  valid_per_epoch: 0.015898s
# [Info]  time_per_epoch: 0.365673s
# [Info]  ETA: 0m 25s
#
# ---------------------epoch 440/500----------------------
# [train] train_loss: 0.104464, train_blue: 0.996440
# [valid] valid_loss: 6.571546, valid_blue: 0.555711
# [Info]  forward_per_epoch: 0.007151s
# [Info]  backward_per_epoch: 0.016988s
# [Info]  valid_per_epoch: 0.015877s
# [Info]  time_per_epoch: 0.366881s
# [Info]  ETA: 0m 22s
#
# ---------------------epoch 450/500----------------------
# [train] train_loss: 0.094177, train_blue: 0.996440
# [valid] valid_loss: 6.886219, valid_blue: 0.693674
# [Info]  forward_per_epoch: 0.007692s
# [Info]  backward_per_epoch: 0.017515s
# [Info]  valid_per_epoch: 0.015900s
# [Info]  time_per_epoch: 0.366769s
# [Info]  ETA: 0m 18s
#
# ---------------------epoch 460/500----------------------
# [train] train_loss: 0.088505, train_blue: 0.996440
# [valid] valid_loss: 6.956192, valid_blue: 0.693674
# [Info]  forward_per_epoch: 0.007129s
# [Info]  backward_per_epoch: 0.017349s
# [Info]  valid_per_epoch: 0.018402s
# [Info]  time_per_epoch: 0.374735s
# [Info]  ETA: 0m 14s
#
# ---------------------epoch 470/500----------------------
# [train] train_loss: 0.084043, train_blue: 0.996440
# [valid] valid_loss: 6.980213, valid_blue: 0.693674
# [Info]  forward_per_epoch: 0.007175s
# [Info]  backward_per_epoch: 0.017007s
# [Info]  valid_per_epoch: 0.015920s
# [Info]  time_per_epoch: 0.380711s
# [Info]  ETA: 0m 11s
#
# ---------------------epoch 480/500----------------------
# [train] train_loss: 0.079860, train_blue: 0.996440
# [valid] valid_loss: 7.171972, valid_blue: 0.693674
# [Info]  forward_per_epoch: 0.007127s
# [Info]  backward_per_epoch: 0.017218s
# [Info]  valid_per_epoch: 0.016061s
# [Info]  time_per_epoch: 0.374046s
# [Info]  ETA: 0m 7s
#
# ---------------------epoch 490/500----------------------
# [train] train_loss: 0.075791, train_blue: 0.996440
# [valid] valid_loss: 7.208867, valid_blue: 0.668740
# [Info]  forward_per_epoch: 0.007147s
# [Info]  backward_per_epoch: 0.017629s
# [Info]  valid_per_epoch: 0.015862s
# [Info]  time_per_epoch: 0.367902s
# [Info]  ETA: 0m 3s
#
# ---------------------epoch 500/500----------------------
# [train] train_loss: 0.071728, train_blue: 0.996440
# [valid] valid_loss: 7.228120, valid_blue: 0.668740
# [Info]  forward_per_epoch: 0.007188s
# [Info]  backward_per_epoch: 0.017413s
# [Info]  valid_per_epoch: 0.015929s
# [Info]  time_per_epoch: 0.365790s
# [Info]  ETA: 0m 0s
#
#
# [Info] train_size: 32, valid_size: 4, dict_size: 175
#
# ---------------------epoch 10/500----------------------
# [train] train_loss: 5.091116, train_blue: 0.587924
# [valid] valid_loss: 5.143525, valid_blue: 0.665900
# [Info]  forward_per_epoch: 0.008805s
# [Info]  backward_per_epoch: 0.021661s
# [Info]  valid_per_epoch: 0.022064s
# [Info]  time_per_epoch: 0.711864s
# [Info]  ETA: 5m 48s
#
# ---------------------epoch 20/500----------------------
# [train] train_loss: 4.942252, train_blue: 0.442198
# [valid] valid_loss: 5.081840, valid_blue: 0.581694
# [Info]  forward_per_epoch: 0.008927s
# [Info]  backward_per_epoch: 0.018605s
# [Info]  valid_per_epoch: 0.022252s
# [Info]  time_per_epoch: 0.708992s
# [Info]  ETA: 5m 40s
# ---------------------epoch 30/500----------------------
# [train] train_loss: 4.419880, train_blue: 0.438481
# [valid] valid_loss: 4.862511, valid_blue: 0.581694
# [Info]  forward_per_epoch: 0.012100s
# [Info]  backward_per_epoch: 0.022885s
# [Info]  valid_per_epoch: 0.022227s
# [Info]  time_per_epoch: 0.716151s
# [Info]  ETA: 5m 36s
#
# ---------------------epoch 40/500----------------------
# [train] train_loss: 4.112756, train_blue: 0.456718
# [valid] valid_loss: 5.125494, valid_blue: 0.555721
# [Info]  forward_per_epoch: 0.008688s
# [Info]  backward_per_epoch: 0.019864s
# [Info]  valid_per_epoch: 0.021795s
# [Info]  time_per_epoch: 0.695919s
# [Info]  ETA: 5m 20s
#
# ---------------------epoch 50/500----------------------
# [train] train_loss: 3.861281, train_blue: 0.431617
# [valid] valid_loss: 5.109168, valid_blue: 0.555721
# [Info]  forward_per_epoch: 0.008876s
# [Info]  backward_per_epoch: 0.021784s
# [Info]  valid_per_epoch: 0.023668s
# [Info]  time_per_epoch: 0.719479s
# [Info]  ETA: 5m 23s
#
# ---------------------epoch 60/500----------------------
# [train] train_loss: 3.622985, train_blue: 0.439941
# [valid] valid_loss: 5.198147, valid_blue: 0.418446
# [Info]  forward_per_epoch: 0.009357s
# [Info]  backward_per_epoch: 0.020638s
# [Info]  valid_per_epoch: 0.021990s
# [Info]  time_per_epoch: 0.715852s
# [Info]  ETA: 5m 14s
#
# ---------------------epoch 70/500----------------------
# [train] train_loss: 3.364187, train_blue: 0.419462
# [valid] valid_loss: 5.376733, valid_blue: 0.555721
# [Info]  forward_per_epoch: 0.008746s
# [Info]  backward_per_epoch: 0.019534s
# [Info]  valid_per_epoch: 0.021957s
# [Info]  time_per_epoch: 0.705785s
# [Info]  ETA: 5m 3s
#
# ---------------------epoch 80/500----------------------
# [train] train_loss: 3.093982, train_blue: 0.448221
# [valid] valid_loss: 5.532542, valid_blue: 0.555721
# [Info]  forward_per_epoch: 0.009021s
# [Info]  backward_per_epoch: 0.021873s
# [Info]  valid_per_epoch: 0.021964s
# [Info]  time_per_epoch: 0.698006s
# [Info]  ETA: 4m 53s
#
# ---------------------epoch 90/500----------------------
# [train] train_loss: 2.819791, train_blue: 0.429932
# [valid] valid_loss: 5.612281, valid_blue: 0.555721
# [Info]  forward_per_epoch: 0.008751s
# [Info]  backward_per_epoch: 0.022085s
# [Info]  valid_per_epoch: 0.021839s
# [Info]  time_per_epoch: 0.693885s
# [Info]  ETA: 4m 44s
#
# ---------------------epoch 100/500----------------------
# [train] train_loss: 2.552728, train_blue: 0.375551
# [valid] valid_loss: 5.754750, valid_blue: 0.555721
# [Info]  forward_per_epoch: 0.008999s
# [Info]  backward_per_epoch: 0.020777s
# [Info]  valid_per_epoch: 0.021923s
# [Info]  time_per_epoch: 0.718516s
# [Info]  ETA: 4m 47s
#
# ---------------------epoch 110/500----------------------
# [train] train_loss: 2.300018, train_blue: 0.361437
# [valid] valid_loss: 5.867501, valid_blue: 0.555721
# [Info]  forward_per_epoch: 0.008809s
# [Info]  backward_per_epoch: 0.019729s
# [Info]  valid_per_epoch: 0.022570s
# [Info]  time_per_epoch: 0.702633s
# [Info]  ETA: 4m 34s
#
# ---------------------epoch 120/500----------------------
# [train] train_loss: 2.069933, train_blue: 0.345542
# [valid] valid_loss: 5.932438, valid_blue: 0.555721
# [Info]  forward_per_epoch: 0.008758s
# [Info]  backward_per_epoch: 0.022624s
# [Info]  valid_per_epoch: 0.021781s
# [Info]  time_per_epoch: 0.717659s
# [Info]  ETA: 4m 32s
#
# ---------------------epoch 130/500----------------------
# [train] train_loss: 1.860797, train_blue: 0.352404
# [valid] valid_loss: 5.923536, valid_blue: 0.555721
# [Info]  forward_per_epoch: 0.008718s
# [Info]  backward_per_epoch: 0.020226s
# [Info]  valid_per_epoch: 0.022284s
# [Info]  time_per_epoch: 0.717088s
# [Info]  ETA: 4m 25s
#
# ---------------------epoch 140/500----------------------
# [train] train_loss: 1.675671, train_blue: 0.368107
# [valid] valid_loss: 6.005326, valid_blue: 0.555721
# [Info]  forward_per_epoch: 0.008903s
# [Info]  backward_per_epoch: 0.020267s
# [Info]  valid_per_epoch: 0.022228s
# [Info]  time_per_epoch: 0.713671s
# [Info]  ETA: 4m 16s
#
# ---------------------epoch 150/500----------------------
# [train] train_loss: 1.506262, train_blue: 0.449235
# [valid] valid_loss: 6.099494, valid_blue: 0.555721
# [Info]  forward_per_epoch: 0.008769s
# [Info]  backward_per_epoch: 0.019229s
# [Info]  valid_per_epoch: 0.022011s
# [Info]  time_per_epoch: 0.714359s
# [Info]  ETA: 4m 10s
#
# ---------------------epoch 160/500----------------------
# [train] train_loss: 1.359859, train_blue: 0.521672
# [valid] valid_loss: 6.374573, valid_blue: 0.555721
# [Info]  forward_per_epoch: 0.009239s
# [Info]  backward_per_epoch: 0.022784s
# [Info]  valid_per_epoch: 0.022083s
# [Info]  time_per_epoch: 0.714572s
# [Info]  ETA: 4m 2s
#
# ---------------------epoch 170/500----------------------
# [train] train_loss: 1.227715, train_blue: 0.614663
# [valid] valid_loss: 6.477473, valid_blue: 0.555721
# [Info]  forward_per_epoch: 0.008698s
# [Info]  backward_per_epoch: 0.020081s
# [Info]  valid_per_epoch: 0.022548s
# [Info]  time_per_epoch: 0.736887s
# [Info]  ETA: 4m 3s
#
# ---------------------epoch 180/500----------------------
# [train] train_loss: 1.108583, train_blue: 0.720473
# [valid] valid_loss: 6.444074, valid_blue: 0.555721
# [Info]  forward_per_epoch: 0.008809s
# [Info]  backward_per_epoch: 0.020607s
# [Info]  valid_per_epoch: 0.021773s
# [Info]  time_per_epoch: 0.715988s
# [Info]  ETA: 3m 49s
#
# ---------------------epoch 190/500----------------------
# [train] train_loss: 1.007479, train_blue: 0.810858
# [valid] valid_loss: 6.732755, valid_blue: 0.555721
# [Info]  forward_per_epoch: 0.008749s
# [Info]  backward_per_epoch: 0.020553s
# [Info]  valid_per_epoch: 0.022003s
# [Info]  time_per_epoch: 0.694086s
# [Info]  ETA: 3m 35s
#
# ---------------------epoch 200/500----------------------
# [train] train_loss: 0.904105, train_blue: 0.871984
# [valid] valid_loss: 6.755150, valid_blue: 0.625710
# [Info]  forward_per_epoch: 0.008785s
# [Info]  backward_per_epoch: 0.025458s
# [Info]  valid_per_epoch: 0.022064s
# [Info]  time_per_epoch: 0.711511s
# [Info]  ETA: 3m 33s
#
# ---------------------epoch 210/500----------------------
# [train] train_loss: 0.814741, train_blue: 0.901881
# [valid] valid_loss: 6.851643, valid_blue: 0.625710
# [Info]  forward_per_epoch: 0.008738s
# [Info]  backward_per_epoch: 0.021126s
# [Info]  valid_per_epoch: 0.021938s
# [Info]  time_per_epoch: 0.695741s
# [Info]  ETA: 3m 21s
#
# ---------------------epoch 220/500----------------------
# [train] train_loss: 0.732861, train_blue: 0.922544
# [valid] valid_loss: 6.914706, valid_blue: 0.625710
# [Info]  forward_per_epoch: 0.008783s
# [Info]  backward_per_epoch: 0.018696s
# [Info]  valid_per_epoch: 0.022067s
# [Info]  time_per_epoch: 0.719025s
# [Info]  ETA: 3m 21s
#
# ---------------------epoch 230/500----------------------
# [train] train_loss: 0.659849, train_blue: 0.944538
# [valid] valid_loss: 7.081840, valid_blue: 0.625710
# [Info]  forward_per_epoch: 0.008793s
# [Info]  backward_per_epoch: 0.020109s
# [Info]  valid_per_epoch: 0.023545s
# [Info]  time_per_epoch: 0.713771s
# [Info]  ETA: 3m 12s
#
# ---------------------epoch 240/500----------------------
# [train] train_loss: 0.594432, train_blue: 0.954558
# [valid] valid_loss: 7.117118, valid_blue: 0.625710
# [Info]  forward_per_epoch: 0.008820s
# [Info]  backward_per_epoch: 0.021623s
# [Info]  valid_per_epoch: 0.021951s
# [Info]  time_per_epoch: 0.701886s
# [Info]  ETA: 3m 2s
#
# ---------------------epoch 250/500----------------------
# [train] train_loss: 0.535288, train_blue: 0.967694
# [valid] valid_loss: 7.168647, valid_blue: 0.625710
# [Info]  forward_per_epoch: 0.008825s
# [Info]  backward_per_epoch: 0.019609s
# [Info]  valid_per_epoch: 0.022039s
# [Info]  time_per_epoch: 0.696384s
# [Info]  ETA: 2m 54s
#
# ---------------------epoch 260/500----------------------
# [train] train_loss: 0.482627, train_blue: 0.978679
# [valid] valid_loss: 7.502927, valid_blue: 0.669099
# [Info]  forward_per_epoch: 0.008823s
# [Info]  backward_per_epoch: 0.020416s
# [Info]  valid_per_epoch: 0.022809s
# [Info]  time_per_epoch: 0.714896s
# [Info]  ETA: 2m 51s
#
# ---------------------epoch 270/500----------------------
# [train] train_loss: 0.438031, train_blue: 0.983120
# [valid] valid_loss: 7.546797, valid_blue: 0.625710
# [Info]  forward_per_epoch: 0.012068s
# [Info]  backward_per_epoch: 0.024785s
# [Info]  valid_per_epoch: 0.022814s
# [Info]  time_per_epoch: 0.715168s
# [Info]  ETA: 2m 44s
#
# ---------------------epoch 280/500----------------------
# [train] train_loss: 0.399969, train_blue: 0.983120
# [valid] valid_loss: 7.610878, valid_blue: 0.625710
# [Info]  forward_per_epoch: 0.008833s
# [Info]  backward_per_epoch: 0.019346s
# [Info]  valid_per_epoch: 0.021954s
# [Info]  time_per_epoch: 0.697474s
# [Info]  ETA: 2m 33s
# ---------------------epoch 290/500----------------------
# [train] train_loss: 0.367284, train_blue: 0.983120
# [valid] valid_loss: 7.673467, valid_blue: 0.625710
# [Info]  forward_per_epoch: 0.008759s
# [Info]  backward_per_epoch: 0.020557s
# [Info]  valid_per_epoch: 0.021725s
# [Info]  time_per_epoch: 0.717854s
# [Info]  ETA: 2m 30s
#
# ---------------------epoch 300/500----------------------
# [train] train_loss: 0.338984, train_blue: 0.985884
# [valid] valid_loss: 7.732186, valid_blue: 0.625710
# [Info]  forward_per_epoch: 0.008786s
# [Info]  backward_per_epoch: 0.020519s
# [Info]  valid_per_epoch: 0.021953s
# [Info]  time_per_epoch: 0.701137s
# [Info]  ETA: 2m 20s
#
# ---------------------epoch 310/500----------------------
# [train] train_loss: 0.314278, train_blue: 0.985884
# [valid] valid_loss: 7.848243, valid_blue: 0.625710
# [Info]  forward_per_epoch: 0.008755s
# [Info]  backward_per_epoch: 0.021389s
# [Info]  valid_per_epoch: 0.027734s
# [Info]  time_per_epoch: 0.709765s
# [Info]  ETA: 2m 14s
#
# ---------------------epoch 320/500----------------------
# [train] train_loss: 0.292557, train_blue: 0.989754
# [valid] valid_loss: 7.907866, valid_blue: 0.608294
# [Info]  forward_per_epoch: 0.009005s
# [Info]  backward_per_epoch: 0.021912s
# [Info]  valid_per_epoch: 0.027329s
# [Info]  time_per_epoch: 0.723459s
# [Info]  ETA: 2m 10s
#
# ---------------------epoch 330/500----------------------
# [train] train_loss: 0.273328, train_blue: 0.989754
# [valid] valid_loss: 7.467903, valid_blue: 0.678703
# [Info]  forward_per_epoch: 0.010617s
# [Info]  backward_per_epoch: 0.022249s
# [Info]  valid_per_epoch: 0.026857s
# [Info]  time_per_epoch: 0.726389s
# [Info]  ETA: 2m 3s
#
# ---------------------epoch 340/500----------------------
# [train] train_loss: 0.256186, train_blue: 0.994680
# [valid] valid_loss: 7.507668, valid_blue: 0.678703
# [Info]  forward_per_epoch: 0.008789s
# [Info]  backward_per_epoch: 0.022869s
# [Info]  valid_per_epoch: 0.022275s
# [Info]  time_per_epoch: 0.692888s
# [Info]  ETA: 1m 50s
#
# ---------------------epoch 350/500----------------------
# [train] train_loss: 0.240807, train_blue: 0.994680
# [valid] valid_loss: 7.545728, valid_blue: 0.678703
# [Info]  forward_per_epoch: 0.008776s
# [Info]  backward_per_epoch: 0.020567s
# [Info]  valid_per_epoch: 0.022160s
# [Info]  time_per_epoch: 0.717558s
# [Info]  ETA: 1m 47s
#
# ---------------------epoch 360/500----------------------
# [train] train_loss: 0.226934, train_blue: 0.994680
# [valid] valid_loss: 7.580988, valid_blue: 0.678703
# [Info]  forward_per_epoch: 0.008733s
# [Info]  backward_per_epoch: 0.021651s
# [Info]  valid_per_epoch: 0.022794s
# [Info]  time_per_epoch: 0.704093s
# [Info]  ETA: 1m 38s
#
# ---------------------epoch 370/500----------------------
# [train] train_loss: 0.214350, train_blue: 0.994680
# [valid] valid_loss: 7.613162, valid_blue: 0.678703
# [Info]  forward_per_epoch: 0.008923s
# [Info]  backward_per_epoch: 0.021852s
# [Info]  valid_per_epoch: 0.022098s
# [Info]  time_per_epoch: 0.696496s
# [Info]  ETA: 1m 30s
#
# ---------------------epoch 380/500----------------------
# [train] train_loss: 0.202872, train_blue: 0.994680
# [valid] valid_loss: 7.642049, valid_blue: 0.678703
# [Info]  forward_per_epoch: 0.008875s
# [Info]  backward_per_epoch: 0.022349s
# [Info]  valid_per_epoch: 0.021943s
# [Info]  time_per_epoch: 0.720020s
# [Info]  ETA: 1m 26s
#
# ---------------------epoch 390/500----------------------
# [train] train_loss: 0.192354, train_blue: 0.994680
# [valid] valid_loss: 7.670083, valid_blue: 0.678703
# [Info]  forward_per_epoch: 0.008725s
# [Info]  backward_per_epoch: 0.023565s
# [Info]  valid_per_epoch: 0.022746s
# [Info]  time_per_epoch: 0.716709s
# [Info]  ETA: 1m 18s
#
# ---------------------epoch 400/500----------------------
# [train] train_loss: 0.182676, train_blue: 0.994680
# [valid] valid_loss: 7.917974, valid_blue: 0.626130
# [Info]  forward_per_epoch: 0.008732s
# [Info]  backward_per_epoch: 0.022369s
# [Info]  valid_per_epoch: 0.021965s
# [Info]  time_per_epoch: 0.700444s
# [Info]  ETA: 1m 10s
#
# ---------------------epoch 410/500----------------------
# [train] train_loss: 0.173735, train_blue: 0.996621
# [valid] valid_loss: 7.957057, valid_blue: 0.626130
# [Info]  forward_per_epoch: 0.008756s
# [Info]  backward_per_epoch: 0.019886s
# [Info]  valid_per_epoch: 0.022493s
# [Info]  time_per_epoch: 0.724301s
# [Info]  ETA: 1m 5s
#
# ---------------------epoch 420/500----------------------
# [train] train_loss: 0.165437, train_blue: 0.998220
# [valid] valid_loss: 7.996401, valid_blue: 0.626130
# [Info]  forward_per_epoch: 0.008767s
# [Info]  backward_per_epoch: 0.023638s
# [Info]  valid_per_epoch: 0.022840s
# [Info]  time_per_epoch: 0.711863s
# [Info]  ETA: 0m 56s
#
# ---------------------epoch 430/500----------------------
# [train] train_loss: 0.157701, train_blue: 0.998220
# [valid] valid_loss: 8.349124, valid_blue: 0.625083
# [Info]  forward_per_epoch: 0.008792s
# [Info]  backward_per_epoch: 0.020190s
# [Info]  valid_per_epoch: 0.022065s
# [Info]  time_per_epoch: 0.714377s
# [Info]  ETA: 0m 50s
#
# ---------------------epoch 440/500----------------------
# [train] train_loss: 0.150452, train_blue: 0.998220
# [valid] valid_loss: 8.388585, valid_blue: 0.625083
# [Info]  forward_per_epoch: 0.008961s
# [Info]  backward_per_epoch: 0.020726s
# [Info]  valid_per_epoch: 0.021890s
# [Info]  time_per_epoch: 0.723579s
# [Info]  ETA: 0m 43s
#
# ---------------------epoch 450/500----------------------
# [train] train_loss: 0.143625, train_blue: 0.998220
# [valid] valid_loss: 8.427504, valid_blue: 0.625083
# [Info]  forward_per_epoch: 0.008764s
# [Info]  backward_per_epoch: 0.022750s
# [Info]  valid_per_epoch: 0.021908s
# [Info]  time_per_epoch: 0.723004s
# [Info]  ETA: 0m 36s
#
# ---------------------epoch 460/500----------------------
# [train] train_loss: 0.137159, train_blue: 0.998220
# [valid] valid_loss: 8.465425, valid_blue: 0.625083
# [Info]  forward_per_epoch: 0.010231s
# [Info]  backward_per_epoch: 0.024527s
# [Info]  valid_per_epoch: 0.022207s
# [Info]  time_per_epoch: 0.718526s
# [Info]  ETA: 0m 28s
#
# ---------------------epoch 470/500----------------------
# [train] train_loss: 0.130999, train_blue: 0.998220
# [valid] valid_loss: 8.502819, valid_blue: 0.625083
# [Info]  forward_per_epoch: 0.008687s
# [Info]  backward_per_epoch: 0.021493s
# [Info]  valid_per_epoch: 0.022176s
# [Info]  time_per_epoch: 0.705725s
# [Info]  ETA: 0m 21s
#
# ---------------------epoch 480/500----------------------
# [train] train_loss: 0.125094, train_blue: 0.998220
# [valid] valid_loss: 8.538128, valid_blue: 0.625083
# [Info]  forward_per_epoch: 0.008690s
# [Info]  backward_per_epoch: 0.019321s
# [Info]  valid_per_epoch: 0.024344s
# [Info]  time_per_epoch: 0.708570s
# [Info]  ETA: 0m 14s
#
# ---------------------epoch 490/500----------------------
# [train] train_loss: 0.119394, train_blue: 0.998220
# [valid] valid_loss: 8.573859, valid_blue: 0.625083
# [Info]  forward_per_epoch: 0.008763s
# [Info]  backward_per_epoch: 0.022614s
# [Info]  valid_per_epoch: 0.021776s
# [Info]  time_per_epoch: 0.702086s
# [Info]  ETA: 0m 7s
#
# ---------------------epoch 500/500----------------------
# [train] train_loss: 0.113854, train_blue: 0.998220
# [valid] valid_loss: 8.607985, valid_blue: 0.625083
# [Info]  forward_per_epoch: 0.008723s
# [Info]  backward_per_epoch: 0.019854s
# [Info]  valid_per_epoch: 0.022959s
# [Info]  time_per_epoch: 0.714008s
# [Info]  ETA: 0m 0s

# %%
# plot the result
fig = plt.gcf()
fig.set_size_inches(16,10)
for i in range(2):
    plt.subplot(2, 2, i * 2 + 1)
    plt.plot(range(epoch), [train_log[i][j]["train_loss"] for j in range(epoch)], label="train_loss")
    plt.plot(range(epoch), [train_log[i][j]["valid_loss"] for j in range(epoch)], label="valid_loss")
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.xticks(range(0, epoch + 1, math.floor(epoch / 10)))
    plt.legend()
    plt.subplot(2, 2, i * 2 + 2)
    plt.plot(range(epoch), [train_log[i][j]["train_blue"] for j in range(epoch)], label="train_blue")
    plt.plot(range(epoch), [train_log[i][j]["valid_blue"] for j in range(epoch)], label="valid_blue")
    plt.xlabel('epoch')
    plt.ylabel('BLEU')
    plt.xticks(range(0, epoch + 1, math.floor(epoch / 10)))
    plt.legend()
    
plt.show()

# %%
###################################################################
#                                                                 #
#                                                                 #
#       caption generating via encoder-decoder pipeline           #
#                                                                 #
#                                                                 #
###################################################################

# initialize the pipeline
encoder_path = "data/encoder_checkpoint_2d.pth"
decoder_path = "data/decoder_checkpoint_2d.pth"
encoder_decoder = EncoderDecoder(encoder_path, decoder_path)

# prepare the dataloader
transform = transforms.Compose([transforms.Resize(IMAGE_SIZE), transforms.ToTensor()])
train_ds = ImageCaptionDataset(root, datasets[-1].transformed_data['train'], transform)
train_dl = DataLoader(train_ds, batch_size=1)
valid_ds = ImageCaptionDataset(root, datasets[-1].transformed_data['test'], transform)
valid_dl = DataLoader(valid_ds, batch_size=1)
dataloader = {
    'train': train_dl,
    'test': valid_dl
}

# caption images
descriptions = {
    'train': [],
    'test': []
}
images = {
    'train': [],
    'test': []
}
for phase in ["train", "test"]:
    for i, (_, image_inputs, caps, cap_lengths) in enumerate(dataloader[phase]):
        image_inputs = Variable(image_inputs).cuda()
        descriptions[phase] += encoder_decoder.generate_text(image_inputs, datasets[-1].dict_idx2word, 50)
        images[phase].append(image_inputs)
        
    # edit the descriptions
    for i in range(len(descriptions[phase])):
        text = descriptions[phase][i].split(" ")
        new = []
        count = 0
        for j in range(len(text)):
            new.append(text[j])
            count += 1
            if count == 12:
                new.append("\n")
                count = 0
        descriptions[phase][i] = " ".join(new)

# %%
fig = plt.gcf()
fig.set_size_inches(8,4 * len(descriptions['train']))
for i in range(len(descriptions['train'])):
    plt.subplot(len(descriptions['train']), 1, i+1)
    plt.imshow(transforms.ToPILImage()(images['train'][i].cpu().view(3, 64, 64)))
    plt.text(80, 32, descriptions['train'][i], fontsize=14)
plt.show()

# %%
fig = plt.gcf()
fig.set_size_inches(8,4 * len(descriptions['test']))
for i in range(len(descriptions['test'])):
    plt.subplot(len(descriptions['test']), 1, i+1)
    plt.imshow(transforms.ToPILImage()(images['test'][i].cpu().view(3, 64, 64)))
    plt.text(80, 32, descriptions['test'][i], fontsize=14)
plt.show()

# %% [markdown]
# ## 2. 3D encoder-decoder for shape captioning

# %%
###################################################################
#                                                                 #
#                                                                 #
#                   training for encoder-decoder                  #
#                                                                 #
#                                                                 #
###################################################################

train_log = []
models = []
for data in datasets:
    print("[Info] train_size: %d, valid_size: %d, dict_size: %d\n" % 
          (data.train_size, data.valid_size, data.dict_size))
    
    # prepare the dataloader
    train_ds = ShapeCaptionDataset(root, data.transformed_data['train'])
    train_dl = DataLoader(train_ds, batch_size=2)
    valid_ds = ShapeCaptionDataset(root, data.transformed_data['valid'])
    valid_dl = DataLoader(valid_ds, batch_size=2)
    dataloader = {
        'train': train_dl,
        'valid': valid_dl
    }

    # # load the pretrained encoder
    # encoder = torch.load("data/encoder.pth").cuda()

    # initialize the encoder
    encoder = Encoder3D().cuda()

    # define the decoder
    input_size = data.dict_size + 1
    hidden_size = 512
    num_layer = 2
    decoder = Decoder(input_size, hidden_size, num_layer).cuda()

    # prepare the training parameters
    # optimizer = optim.Adam(list(decoder.parameters()) + list(encoder.fc_layer.parameters()), lr=0.001)
    params = list(decoder.parameters()) + list(encoder.conv_layer.parameters()) + list(encoder.fc_layer.parameters())
    optimizer = optim.Adam(params, lr=0.0001)
    criterion = nn.CrossEntropyLoss()
    # criterion = nn.NLLLoss()
    epoch = 100
    verbose = 10

    # training
    encoder_decoder_solver = EncoderDecoderSolver(optimizer, criterion, model_type="3d")
    encoder_decoder_solver.train(encoder, decoder, dataloader, data.corpus, data.dict_idx2word, epoch, verbose)
    
    # save
    train_log.append(encoder_decoder_solver.log)
    models.append((encoder, decoder))
    print()
# Out:
# [Info] train_size: 16, valid_size: 2, dict_size: 132
#
# ---------------------epoch 10/100----------------------
# [train] train_loss: 3.612279, train_blue: 0.405192
# [valid] valid_loss: 4.119368, valid_blue: 0.739222
# [Info]  forward_per_epoch: 0.382104s
# [Info]  backward_per_epoch: 0.962064s
# [Info]  valid_per_epoch: 0.045101s
# [Info]  time_per_epoch: 3.040701s
# [Info]  ETA: 4m 33s
#
# ---------------------epoch 20/100----------------------
# [train] train_loss: 2.404480, train_blue: 0.361731
# [valid] valid_loss: 4.651170, valid_blue: 0.585485
# [Info]  forward_per_epoch: 0.389456s
# [Info]  backward_per_epoch: 0.960065s
# [Info]  valid_per_epoch: 0.048806s
# [Info]  time_per_epoch: 3.066955s
# [Info]  ETA: 4m 5s
#
# ---------------------epoch 30/100----------------------
# [train] train_loss: 1.661005, train_blue: 0.427353
# [valid] valid_loss: 4.922598, valid_blue: 0.507704
# [Info]  forward_per_epoch: 0.388144s
# [Info]  backward_per_epoch: 0.959356s
# [Info]  valid_per_epoch: 0.045298s
# [Info]  time_per_epoch: 3.029268s
# [Info]  ETA: 3m 32s
#
# ---------------------epoch 40/100----------------------
# [train] train_loss: 1.201026, train_blue: 0.695475
# [valid] valid_loss: 5.196979, valid_blue: 0.539937
# [Info]  forward_per_epoch: 0.384974s
# [Info]  backward_per_epoch: 0.961497s
# [Info]  valid_per_epoch: 0.045199s
# [Info]  time_per_epoch: 3.011611s
# [Info]  ETA: 3m 0s
#
# ---------------------epoch 50/100----------------------
# [train] train_loss: 0.904379, train_blue: 0.857460
# [valid] valid_loss: 5.431504, valid_blue: 0.530777
# [Info]  forward_per_epoch: 0.388611s
# [Info]  backward_per_epoch: 0.974208s
# [Info]  valid_per_epoch: 0.045415s
# [Info]  time_per_epoch: 3.074484s
# [Info]  ETA: 2m 33s
#
# ---------------------epoch 60/100----------------------
# [train] train_loss: 0.667382, train_blue: 0.897330
# [valid] valid_loss: 5.753322, valid_blue: 0.682055
# [Info]  forward_per_epoch: 0.386664s
# [Info]  backward_per_epoch: 0.977936s
# [Info]  valid_per_epoch: 0.045648s
# [Info]  time_per_epoch: 3.046300s
# [Info]  ETA: 2m 1s
#
# ---------------------epoch 70/100----------------------
# [train] train_loss: 0.497129, train_blue: 0.928115
# [valid] valid_loss: 6.055112, valid_blue: 0.682055
# [Info]  forward_per_epoch: 0.386968s
# [Info]  backward_per_epoch: 0.972741s
# [Info]  valid_per_epoch: 0.045436s
# [Info]  time_per_epoch: 3.091359s
# [Info]  ETA: 1m 32s
#
# ---------------------epoch 80/100----------------------
# [train] train_loss: 0.356637, train_blue: 0.964757
# [valid] valid_loss: 6.303467, valid_blue: 0.682055
# [Info]  forward_per_epoch: 0.386308s
# [Info]  backward_per_epoch: 0.965598s
# [Info]  valid_per_epoch: 0.046190s
# [Info]  time_per_epoch: 3.041908s
# [Info]  ETA: 1m 0s
#
# ---------------------epoch 90/100----------------------
# [train] train_loss: 0.259865, train_blue: 0.964757
# [valid] valid_loss: 6.539496, valid_blue: 0.682055
# [Info]  forward_per_epoch: 0.389846s
# [Info]  backward_per_epoch: 0.974686s
# [Info]  valid_per_epoch: 0.045631s
# [Info]  time_per_epoch: 3.105257s
# [Info]  ETA: 0m 31s
#
# ---------------------epoch 100/100----------------------
# [train] train_loss: 0.199077, train_blue: 0.971532
# [valid] valid_loss: 6.726168, valid_blue: 0.682055
# [Info]  forward_per_epoch: 0.386595s
# [Info]  backward_per_epoch: 0.977525s
# [Info]  valid_per_epoch: 0.045386s
# [Info]  time_per_epoch: 3.104325s
# [Info]  ETA: 0m 0s
#
#
# [Info] train_size: 32, valid_size: 4, dict_size: 175
#
# ---------------------epoch 10/100----------------------
# [train] train_loss: 3.270238, train_blue: 0.416345
# [valid] valid_loss: 5.160153, valid_blue: 0.626130
# [Info]  forward_per_epoch: 0.768830s
# [Info]  backward_per_epoch: 1.931719s
# [Info]  valid_per_epoch: 0.083089s
# [Info]  time_per_epoch: 6.073277s
# [Info]  ETA: 9m 6s
#
# ---------------------epoch 20/100----------------------
# [train] train_loss: 2.128039, train_blue: 0.373614
# [valid] valid_loss: 5.569290, valid_blue: 0.696119
# [Info]  forward_per_epoch: 0.769220s
# [Info]  backward_per_epoch: 1.921348s
# [Info]  valid_per_epoch: 0.082766s
# [Info]  time_per_epoch: 6.057166s
# [Info]  ETA: 8m 4s
#
# ---------------------epoch 30/100----------------------
# [train] train_loss: 1.363051, train_blue: 0.510534
# [valid] valid_loss: 5.837177, valid_blue: 0.696119
# [Info]  forward_per_epoch: 0.767387s
# [Info]  backward_per_epoch: 1.931418s
# [Info]  valid_per_epoch: 0.082824s
# [Info]  time_per_epoch: 6.201662s
# [Info]  ETA: 7m 14s
#
# ---------------------epoch 40/100----------------------
# [train] train_loss: 0.949181, train_blue: 0.754348
# [valid] valid_loss: 6.399156, valid_blue: 0.696119
# [Info]  forward_per_epoch: 0.767577s
# [Info]  backward_per_epoch: 1.929831s
# [Info]  valid_per_epoch: 0.082882s
# [Info]  time_per_epoch: 6.038494s
# [Info]  ETA: 6m 2s
#
# ---------------------epoch 50/100----------------------
# [train] train_loss: 0.653738, train_blue: 0.851330
# [valid] valid_loss: 6.957375, valid_blue: 0.696119
# [Info]  forward_per_epoch: 0.767910s
# [Info]  backward_per_epoch: 1.928916s
# [Info]  valid_per_epoch: 0.082959s
# [Info]  time_per_epoch: 6.011578s
# [Info]  ETA: 5m 0s
#
# ---------------------epoch 60/100----------------------
# [train] train_loss: 0.416709, train_blue: 0.866224
# [valid] valid_loss: 7.349633, valid_blue: 0.696119
# [Info]  forward_per_epoch: 0.772929s
# [Info]  backward_per_epoch: 1.948222s
# [Info]  valid_per_epoch: 0.083123s
# [Info]  time_per_epoch: 6.120788s
# [Info]  ETA: 4m 4s
#
# ---------------------epoch 70/100----------------------
# [train] train_loss: 0.304817, train_blue: 0.909180
# [valid] valid_loss: 7.674324, valid_blue: 0.696119
# [Info]  forward_per_epoch: 0.769762s
# [Info]  backward_per_epoch: 1.928656s
# [Info]  valid_per_epoch: 0.082796s
# [Info]  time_per_epoch: 6.220411s
# [Info]  ETA: 3m 6s
#
# ---------------------epoch 80/100----------------------
# [train] train_loss: 0.227936, train_blue: 0.950316
# [valid] valid_loss: 7.967812, valid_blue: 0.696119
# [Info]  forward_per_epoch: 0.771536s
# [Info]  backward_per_epoch: 1.937585s
# [Info]  valid_per_epoch: 0.083182s
# [Info]  time_per_epoch: 6.061904s
# [Info]  ETA: 2m 1s
#
# ---------------------epoch 90/100----------------------
# [train] train_loss: 0.170222, train_blue: 0.971599
# [valid] valid_loss: 8.220821, valid_blue: 0.696119
# [Info]  forward_per_epoch: 0.769407s
# [Info]  backward_per_epoch: 1.928597s
# [Info]  valid_per_epoch: 0.083368s
# [Info]  time_per_epoch: 6.061165s
# [Info]  ETA: 1m 0s
#
# ---------------------epoch 100/100----------------------
# [train] train_loss: 0.127010, train_blue: 0.993734
# [valid] valid_loss: 8.424074, valid_blue: 0.696119
# [Info]  forward_per_epoch: 0.768791s
# [Info]  backward_per_epoch: 1.928142s
# [Info]  valid_per_epoch: 0.084153s
# [Info]  time_per_epoch: 6.225787s
# [Info]  ETA: 0m 0s

# %%
# plot the result
fig = plt.gcf()
fig.set_size_inches(16,10)
for i in range(2):
    plt.subplot(2, 2, i * 2 + 1)
    plt.plot(range(epoch), [train_log[i][j]["train_loss"] for j in range(epoch)], label="train_loss")
    plt.plot(range(epoch), [train_log[i][j]["valid_loss"] for j in range(epoch)], label="valid_loss")
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.xticks(range(0, epoch + 1, math.floor(epoch / 10)))
    plt.legend()
    plt.subplot(2, 2, i * 2 + 2)
    plt.plot(range(epoch), [np.mean(train_log[i][j]["train_blue"]) for j in range(epoch)], label="train_blue")
    plt.plot(range(epoch), [np.mean(train_log[i][j]["valid_blue"]) for j in range(epoch)], label="valid_blue")
    plt.xlabel('epoch')
    plt.ylabel('BLEU')
    plt.xticks(range(0, epoch + 1, math.floor(epoch / 10)))
    plt.legend()
    
plt.show()

# %%
###################################################################
#                                                                 #
#                                                                 #
#       caption generating via encoder-decoder pipeline           #
#                                                                 #
#                                                                 #
###################################################################

# initialize the pipeline
encoder_path = "data/encoder_checkpoint_3d.pth"
decoder_path = "data/decoder_checkpoint_3d.pth"
encoder_decoder = EncoderDecoder3D(encoder_path, decoder_path)

# prepare the dataloader
train_ds = ShapeCaptionDataset(root, datasets[-1].transformed_data['train'])
train_dl = DataLoader(train_ds, batch_size=1)
valid_ds = ShapeCaptionDataset(root, datasets[-1].transformed_data['valid'])
valid_dl = DataLoader(valid_ds, batch_size=1)
dataloader = {
    'train': train_dl,
    'valid': valid_dl
}

# caption shapes
descriptions = {
    'train': [],
    'valid': []
}
images = {
    'train': [],
    'valid': []
}
for phase in ["train", "valid"]:
    for i, (_, shape_inputs, caps, cap_lengths) in enumerate(dataloader[phase]):
        shape_inputs = Variable(shape_inputs).cuda()
        descriptions[phase] += encoder_decoder.generate_text(shape_inputs, datasets[-1].dict_idx2word, 50)
        shape[phase].append(shape_inputs)
        
    # edit the descriptions
    for i in range(len(descriptions[phase])):
        text = descriptions[phase][i].split(" ")
        new = []
        count = 0
        for j in range(len(text)):
            new.append(text[j])
            count += 1
            if count == 12:
                new.append("\n")
                count = 0
        descriptions[phase][i] = " ".join(new)
