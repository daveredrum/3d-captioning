# %% [markdown]
# # 3D Shape/Scene Captioning
# ## 0. settings

# %%
import pandas 
import numpy as np
import os
import re
import operator
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from data import *
from constants import *
from models import *
from solver import *
import matplotlib.pyplot as plt
# Out:
# /home/davech2y/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="2"
os.environ["CUDA_LAUNCH_BLOCKING"]="1"
root = "/mnt/raid/davech2y/ShapeNetCore_vol/nrrd_256_filter_div_32_solid/"
sizes = [
    [16, 2, 2],
    [32, 4, 4]
]

# %%
datasets = []
for i, size in enumerate(sizes):
    datasets.append(Caption(pandas.read_csv("captions.tablechair.csv"), size))
    print("[set %d]: total_size: %d, train_size: %d, valid_size: %d, test_size: %d, vocal_size: %d" 
          % (i+1, 
             datasets[-1].total_size, 
             datasets[-1].train_size, 
             datasets[-1].valid_size,
             datasets[-1].test_size,
             datasets[-1].dict_size))
# Out:
# [set 1]: total_size: 20, train_size: 16, valid_size: 2, test_size: 2, vocal_size: 132
# [set 2]: total_size: 40, train_size: 32, valid_size: 4, test_size: 4, vocal_size: 175

# %% [markdown]
# ## 1. 2D encoder-decoder for image captioning

# %%
###################################################################
#                                                                 #
#                                                                 #
#                   training for encoder-decoder                  #
#                                                                 #
#                                                                 #
###################################################################

train_log = []
models = []
for data in datasets:
    print("[Info] train_size: %d, valid_size: %d, dict_size: %d\n" % 
          (data.train_size, data.valid_size, data.dict_size))
    
    # prepare the dataloader
    transform = transforms.Compose([transforms.Resize(IMAGE_SIZE), transforms.ToTensor()])
    train_ds = ImageCaptionDataset(root, data.transformed_data['train'], transform)
    train_dl = DataLoader(train_ds, batch_size=50)
    valid_ds = ImageCaptionDataset(root, data.transformed_data['valid'], transform)
    valid_dl = DataLoader(valid_ds, batch_size=50)
    dataloader = {
        'train': train_dl,
        'valid': valid_dl
    }

    # # load the pretrained encoder
    # encoder = torch.load("data/encoder.pth").cuda()

    # initialize the encoder
    encoder = Encoder2D().cuda()

    # define the decoder
    input_size = data.dict_size + 1
    hidden_size = 512
    num_layer = 2
    decoder = Decoder(input_size, hidden_size, num_layer).cuda()

    # prepare the training parameters
    # optimizer = optim.Adam(list(decoder.parameters()) + list(encoder.fc_layer.parameters()), lr=0.001)
    params = list(decoder.parameters()) + list(encoder.conv_layer.parameters()) + list(encoder.fc_layer.parameters())
    optimizer = optim.Adam(params, lr=0.0001)
    criterion = nn.CrossEntropyLoss()
    # criterion = nn.NLLLoss()
    epoch = 100
    verbose = 10

    # training
    encoder_decoder_solver = EncoderDecoderSolver(optimizer, criterion, model_type="3d")
    encoder_decoder_solver.train(encoder, decoder, dataloader, data.corpus, data.dict_idx2word, epoch, verbose, model_type="3d")
    
    # save
    train_log.append(encoder_decoder_solver.log)
    models.append((encoder, decoder))
    print()

# %%
sum([np.prod(p.size()) for p in encoder.parameters()])
# Out:
# 2719234

# %%
sum(p.numel() for p in encoder.parameters() if p.requires_grad)
# Out:
# 2719234

# %%
# plot the result
fig = plt.gcf()
fig.set_size_inches(16,10)
for i in range(2):
    plt.subplot(2, 2, i * 2 + 1)
    plt.plot(range(epoch), [train_log[i][j]["train_loss"] for j in range(epoch)], label="train_loss")
    plt.plot(range(epoch), [train_log[i][j]["valid_loss"] for j in range(epoch)], label="valid_loss")
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.xticks(range(0, epoch + 1, math.floor(epoch / 10)))
    plt.legend()
    plt.subplot(2, 2, i * 2 + 2)
    plt.plot(range(epoch), [train_log[i][j]["train_blue"] for j in range(epoch)], label="train_blue")
    plt.plot(range(epoch), [train_log[i][j]["valid_blue"] for j in range(epoch)], label="valid_blue")
    plt.xlabel('epoch')
    plt.ylabel('BLEU')
    plt.xticks(range(0, epoch + 1, math.floor(epoch / 10)))
    plt.legend()
    
plt.show()

# %%
###################################################################
#                                                                 #
#                                                                 #
#       caption generating via encoder-decoder pipeline           #
#                                                                 #
#                                                                 #
###################################################################

# initialize the pipeline
encoder_path = "data/encoder_checkpoint_2d.pth"
decoder_path = "data/decoder_checkpoint_2d.pth"
encoder_decoder = EncoderDecoder(encoder_path, decoder_path)

# prepare the dataloader
transform = transforms.Compose([transforms.Resize(IMAGE_SIZE), transforms.ToTensor()])
train_ds = ImageCaptionDataset(root, datasets[-1].transformed_data['train'], transform)
train_dl = DataLoader(train_ds, batch_size=1)
valid_ds = ImageCaptionDataset(root, datasets[-1].transformed_data['test'], transform)
valid_dl = DataLoader(valid_ds, batch_size=1)
dataloader = {
    'train': train_dl,
    'test': valid_dl
}

# caption images
descriptions = {
    'train': [],
    'test': []
}
images = {
    'train': [],
    'test': []
}
for phase in ["train", "test"]:
    for i, (_, image_inputs, caps, cap_lengths) in enumerate(dataloader[phase]):
        image_inputs = Variable(image_inputs).cuda()
        descriptions[phase] += encoder_decoder.generate_text(image_inputs, datasets[-1].dict_idx2word, 50)
        images[phase].append(image_inputs)
        
    # edit the descriptions
    for i in range(len(descriptions[phase])):
        text = descriptions[phase][i].split(" ")
        new = []
        count = 0
        for j in range(len(text)):
            new.append(text[j])
            count += 1
            if count == 12:
                new.append("\n")
                count = 0
        descriptions[phase][i] = " ".join(new)

# %%
fig = plt.gcf()
fig.set_size_inches(8,4 * len(descriptions['train']))
fig.set_facecolor('white')
for i in range(len(descriptions['train'])):
    plt.subplot(len(descriptions['train']), 1, i+1)
    plt.imshow(transforms.ToPILImage()(images['train'][i].cpu().view(3, 64, 64)))
    plt.text(80, 32, descriptions['train'][i], fontsize=14)
plt.show()

# %%
fig = plt.gcf()
fig.set_size_inches(8,4 * len(descriptions['test']))
fig.set_facecolor('white')
for i in range(len(descriptions['test'])):
    plt.subplot(len(descriptions['test']), 1, i+1)
    plt.imshow(transforms.ToPILImage()(images['test'][i].cpu().view(3, 64, 64)))
    plt.text(80, 32, descriptions['test'][i], fontsize=14)
plt.show()

# %% [markdown]
# ## 2. 3D encoder-decoder for shape captioning

# %%
###################################################################
#                                                                 #
#                                                                 #
#                   training for encoder-decoder                  #
#                                                                 #
#                                                                 #
###################################################################

train_log = []
for data in datasets:
    print("[Info] train_size: %d, valid_size: %d, dict_size: %d\n" % 
          (data.train_size, data.valid_size, data.dict_size))
    
    # prepare the dataloader
    train_ds = ShapeCaptionDataset(
        root, 
        data.transformed_data['train'],
        mode="hdf5", 
        database="/mnt/raid/davech2y/ShapeNetCore_vol/nrrd_256_filter_div_32_solid.hdf5"
    )
    train_dl = DataLoader(train_ds, batch_size=2)
    valid_ds = ShapeCaptionDataset(
        root, 
        data.transformed_data['valid'],
        mode="hdf5", 
        database="/mnt/raid/davech2y/ShapeNetCore_vol/nrrd_256_filter_div_32_solid.hdf5"
    )
    valid_dl = DataLoader(valid_ds, batch_size=2)
    dataloader = {
        'train': train_dl,
        'valid': valid_dl
    }

    # # load the pretrained encoder
    # encoder = torch.load("data/encoder.pth").cuda()

    # initialize the encoder
    encoder = Encoder3D().cuda()

    # define the decoder
    input_size = data.dict_size + 1
    hidden_size = 512
    num_layer = 2
    decoder = Decoder(input_size, hidden_size, num_layer).cuda()

    # prepare the training parameters
    # optimizer = optim.Adam(list(decoder.parameters()) + list(encoder.fc_layer.parameters()), lr=0.001)
    params = list(decoder.parameters()) + list(encoder.conv_layer.parameters()) + list(encoder.fc_layer.parameters())
    optimizer = optim.Adam(params, lr=0.0001)
    criterion = nn.CrossEntropyLoss()
    # criterion = nn.NLLLoss()
    epoch = 200
    verbose = 10

    # training
    encoder_decoder_solver = EncoderDecoderSolver(optimizer, criterion, model_type="3d")
    encoder_decoder_solver.train(encoder, decoder, dataloader, data.corpus, data.dict_idx2word, epoch, verbose, model_type="3d")
    
    # save
    train_log.append(encoder_decoder_solver.log)
    torch.save(encoder, "models/encoder_jupyter_%s_ts%d_bs%d_vocal%d.pth"  % ("3d", data.train_size, epoch, input_size))
    torch.save(decoder, "models/decoder_jupyter_%s_ts%d_bs%d_vocal%d.pth"  % ("3d", data.train_size, epoch, input_size))
    print()
# Out:
# [Info] train_size: 16, valid_size: 2, dict_size: 132
#
# ---------------------epoch 10/200----------------------
# [train] train_loss: 3.587133, train_blue: 0.414685
# [valid] valid_loss: 4.141116, valid_blue: 0.555711
# [Info]  forward_per_epoch: 0.037514s
# [Info]  backward_per_epoch: 0.106376s
# [Info]  valid_per_epoch: 0.015946s
# [Info]  time_per_epoch: 0.194804s
# [Info]  ETA: 0m 37s
#
# ---------------------epoch 20/200----------------------
# [train] train_loss: 2.430432, train_blue: 0.395789
# [valid] valid_loss: 4.797477, valid_blue: 0.548014
# [Info]  forward_per_epoch: 0.037708s
# [Info]  backward_per_epoch: 0.108008s
# [Info]  valid_per_epoch: 0.016764s
# [Info]  time_per_epoch: 0.198072s
# [Info]  ETA: 0m 35s
#
# ---------------------epoch 30/200----------------------
# [train] train_loss: 1.678464, train_blue: 0.403981
# [valid] valid_loss: 5.001642, valid_blue: 0.714288
# [Info]  forward_per_epoch: 0.035702s
# [Info]  backward_per_epoch: 0.106829s
# [Info]  valid_per_epoch: 0.016963s
# [Info]  time_per_epoch: 0.193300s
# [Info]  ETA: 0m 32s
#
# ---------------------epoch 40/200----------------------
# [train] train_loss: 1.227015, train_blue: 0.670981
# [valid] valid_loss: 5.479060, valid_blue: 0.693674
# [Info]  forward_per_epoch: 0.036846s
# [Info]  backward_per_epoch: 0.107229s
# [Info]  valid_per_epoch: 0.016587s
# [Info]  time_per_epoch: 0.196319s
# [Info]  ETA: 0m 31s
#
# ---------------------epoch 50/200----------------------
# [train] train_loss: 0.946500, train_blue: 0.820320
# [valid] valid_loss: 5.470303, valid_blue: 0.668740
# [Info]  forward_per_epoch: 0.038878s
# [Info]  backward_per_epoch: 0.113875s
# [Info]  valid_per_epoch: 0.017341s
# [Info]  time_per_epoch: 0.208551s
# [Info]  ETA: 0m 31s
#
# ---------------------epoch 60/200----------------------
# [train] train_loss: 0.729145, train_blue: 0.903305
# [valid] valid_loss: 5.925049, valid_blue: 0.636508
# [Info]  forward_per_epoch: 0.038623s
# [Info]  backward_per_epoch: 0.112506s
# [Info]  valid_per_epoch: 0.017175s
# [Info]  time_per_epoch: 0.212338s
# [Info]  ETA: 0m 29s
#
# ---------------------epoch 70/200----------------------
# [train] train_loss: 0.561759, train_blue: 0.923878
# [valid] valid_loss: 6.154927, valid_blue: 0.636508
# [Info]  forward_per_epoch: 0.035894s
# [Info]  backward_per_epoch: 0.109717s
# [Info]  valid_per_epoch: 0.017908s
# [Info]  time_per_epoch: 0.199318s
# [Info]  ETA: 0m 25s
#
# ---------------------epoch 80/200----------------------
# [train] train_loss: 0.437338, train_blue: 0.962889
# [valid] valid_loss: 6.359762, valid_blue: 0.636508
# [Info]  forward_per_epoch: 0.037627s
# [Info]  backward_per_epoch: 0.109777s
# [Info]  valid_per_epoch: 0.017329s
# [Info]  time_per_epoch: 0.200085s
# [Info]  ETA: 0m 24s
#
# ---------------------epoch 90/200----------------------
# [train] train_loss: 0.346314, train_blue: 0.984318
# [valid] valid_loss: 6.547931, valid_blue: 0.636508
# [Info]  forward_per_epoch: 0.035477s
# [Info]  backward_per_epoch: 0.105148s
# [Info]  valid_per_epoch: 0.016982s
# [Info]  time_per_epoch: 0.189688s
# [Info]  ETA: 0m 20s
#
# ---------------------epoch 100/200----------------------
# [train] train_loss: 0.271343, train_blue: 0.987878
# [valid] valid_loss: 6.682606, valid_blue: 0.636508
# [Info]  forward_per_epoch: 0.037201s
# [Info]  backward_per_epoch: 0.107493s
# [Info]  valid_per_epoch: 0.015950s
# [Info]  time_per_epoch: 0.196734s
# [Info]  ETA: 0m 19s
#
# ---------------------epoch 110/200----------------------
# [train] train_loss: 0.215417, train_blue: 0.987878
# [valid] valid_loss: 6.805246, valid_blue: 0.636508
# [Info]  forward_per_epoch: 0.037676s
# [Info]  backward_per_epoch: 0.109815s
# [Info]  valid_per_epoch: 0.016355s
# [Info]  time_per_epoch: 0.197832s
# [Info]  ETA: 0m 17s
#
# ---------------------epoch 120/200----------------------
# [train] train_loss: 0.165676, train_blue: 0.992920
# [valid] valid_loss: 6.907445, valid_blue: 0.636508
# [Info]  forward_per_epoch: 0.035390s
# [Info]  backward_per_epoch: 0.111141s
# [Info]  valid_per_epoch: 0.018143s
# [Info]  time_per_epoch: 0.199468s
# [Info]  ETA: 0m 15s
#
# ---------------------epoch 130/200----------------------
# [train] train_loss: 0.117298, train_blue: 0.992920
# [valid] valid_loss: 6.980219, valid_blue: 0.636508
# [Info]  forward_per_epoch: 0.038689s
# [Info]  backward_per_epoch: 0.113703s
# [Info]  valid_per_epoch: 0.017605s
# [Info]  time_per_epoch: 0.209854s
# [Info]  ETA: 0m 14s
#
# ---------------------epoch 140/200----------------------
# [train] train_loss: 0.087239, train_blue: 0.992920
# [valid] valid_loss: 7.068792, valid_blue: 0.636508
# [Info]  forward_per_epoch: 0.036952s
# [Info]  backward_per_epoch: 0.109755s
# [Info]  valid_per_epoch: 0.016793s
# [Info]  time_per_epoch: 0.198495s
# [Info]  ETA: 0m 11s
#
# ---------------------epoch 150/200----------------------
# [train] train_loss: 0.070196, train_blue: 0.992920
# [valid] valid_loss: 7.163228, valid_blue: 0.636508
# [Info]  forward_per_epoch: 0.038046s
# [Info]  backward_per_epoch: 0.113838s
# [Info]  valid_per_epoch: 0.017230s
# [Info]  time_per_epoch: 0.206553s
# [Info]  ETA: 0m 10s
#
# ---------------------epoch 160/200----------------------
# [train] train_loss: 0.058147, train_blue: 0.996119
# [valid] valid_loss: 7.252180, valid_blue: 0.636508
# [Info]  forward_per_epoch: 0.037589s
# [Info]  backward_per_epoch: 0.119675s
# [Info]  valid_per_epoch: 0.017469s
# [Info]  time_per_epoch: 0.209745s
# [Info]  ETA: 0m 8s
#
# ---------------------epoch 170/200----------------------
# [train] train_loss: 0.049003, train_blue: 1.000000
# [valid] valid_loss: 7.334509, valid_blue: 0.636508
# [Info]  forward_per_epoch: 0.036567s
# [Info]  backward_per_epoch: 0.114874s
# [Info]  valid_per_epoch: 0.017388s
# [Info]  time_per_epoch: 0.203276s
# [Info]  ETA: 0m 6s
#
# ---------------------epoch 180/200----------------------
# [train] train_loss: 0.041861, train_blue: 1.000000
# [valid] valid_loss: 7.411355, valid_blue: 0.636508
# [Info]  forward_per_epoch: 0.039696s
# [Info]  backward_per_epoch: 0.115259s
# [Info]  valid_per_epoch: 0.017557s
# [Info]  time_per_epoch: 0.212400s
# [Info]  ETA: 0m 4s
#
# ---------------------epoch 190/200----------------------
# [train] train_loss: 0.036162, train_blue: 1.000000
# [valid] valid_loss: 7.482688, valid_blue: 0.636508
# [Info]  forward_per_epoch: 0.037328s
# [Info]  backward_per_epoch: 0.112694s
# [Info]  valid_per_epoch: 0.015895s
# [Info]  time_per_epoch: 0.202637s
# [Info]  ETA: 0m 2s
#
# ---------------------epoch 200/200----------------------
# [train] train_loss: 0.031542, train_blue: 1.000000
# [valid] valid_loss: 7.550005, valid_blue: 0.636508
# [Info]  forward_per_epoch: 0.038543s
# [Info]  backward_per_epoch: 0.114104s
# [Info]  valid_per_epoch: 0.015856s
# [Info]  time_per_epoch: 0.205994s
# [Info]  ETA: 0m 0s
#
#
# [Info] train_size: 32, valid_size: 4, dict_size: 175
#
# ---------------------epoch 10/200----------------------
# [train] train_loss: 3.215021, train_blue: 0.448432
# [valid] valid_loss: 5.289643, valid_blue: 0.607865
# [Info]  forward_per_epoch: 0.070293s
# [Info]  backward_per_epoch: 0.217987s
# [Info]  valid_per_epoch: 0.024868s
# [Info]  time_per_epoch: 0.381628s
# [Info]  ETA: 1m 12s
#
# ---------------------epoch 20/200----------------------
# [train] train_loss: 2.093507, train_blue: 0.334385
# [valid] valid_loss: 5.902496, valid_blue: 0.696119
# [Info]  forward_per_epoch: 0.074573s
# [Info]  backward_per_epoch: 0.219670s
# [Info]  valid_per_epoch: 0.024409s
# [Info]  time_per_epoch: 0.390981s
# [Info]  ETA: 1m 10s
#
# ---------------------epoch 30/200----------------------
# [train] train_loss: 1.406987, train_blue: 0.484341
# [valid] valid_loss: 6.292669, valid_blue: 0.696119
# [Info]  forward_per_epoch: 0.074010s
# [Info]  backward_per_epoch: 0.225517s
# [Info]  valid_per_epoch: 0.025266s
# [Info]  time_per_epoch: 0.394761s
# [Info]  ETA: 1m 7s
#
# ---------------------epoch 40/200----------------------
# [train] train_loss: 0.943501, train_blue: 0.762453
# [valid] valid_loss: 6.406753, valid_blue: 0.709591
# [Info]  forward_per_epoch: 0.070907s
# [Info]  backward_per_epoch: 0.213704s
# [Info]  valid_per_epoch: 0.025413s
# [Info]  time_per_epoch: 0.380040s
# [Info]  ETA: 1m 0s
#
# ---------------------epoch 50/200----------------------
# [train] train_loss: 0.676581, train_blue: 0.840799
# [valid] valid_loss: 6.766058, valid_blue: 0.696119
# [Info]  forward_per_epoch: 0.070843s
# [Info]  backward_per_epoch: 0.207355s
# [Info]  valid_per_epoch: 0.024353s
# [Info]  time_per_epoch: 0.372214s
# [Info]  ETA: 0m 55s
# ---------------------epoch 60/200----------------------
# [train] train_loss: 0.494603, train_blue: 0.875528
# [valid] valid_loss: 7.042489, valid_blue: 0.696119
# [Info]  forward_per_epoch: 0.073300s
# [Info]  backward_per_epoch: 0.218994s
# [Info]  valid_per_epoch: 0.024537s
# [Info]  time_per_epoch: 0.387882s
# [Info]  ETA: 0m 54s
#
# ---------------------epoch 70/200----------------------
# [train] train_loss: 0.320219, train_blue: 0.907366
# [valid] valid_loss: 7.309795, valid_blue: 0.696119
# [Info]  forward_per_epoch: 0.071638s
# [Info]  backward_per_epoch: 0.222020s
# [Info]  valid_per_epoch: 0.030882s
# [Info]  time_per_epoch: 0.391504s
# [Info]  ETA: 0m 50s
#
# ---------------------epoch 80/200----------------------
# [train] train_loss: 0.223643, train_blue: 0.950481
# [valid] valid_loss: 7.563165, valid_blue: 0.696119
# [Info]  forward_per_epoch: 0.073713s
# [Info]  backward_per_epoch: 0.224578s
# [Info]  valid_per_epoch: 0.022939s
# [Info]  time_per_epoch: 0.391283s
# [Info]  ETA: 0m 46s
#
# ---------------------epoch 90/200----------------------
# [train] train_loss: 0.167712, train_blue: 0.962378
# [valid] valid_loss: 8.136408, valid_blue: 0.696119
# [Info]  forward_per_epoch: 0.070578s
# [Info]  backward_per_epoch: 0.216711s
# [Info]  valid_per_epoch: 0.023983s
# [Info]  time_per_epoch: 0.377411s
# [Info]  ETA: 0m 41s
#
# ---------------------epoch 100/200----------------------
# [train] train_loss: 0.126515, train_blue: 0.975535
# [valid] valid_loss: 8.297047, valid_blue: 0.696119
# [Info]  forward_per_epoch: 0.072269s
# [Info]  backward_per_epoch: 0.222939s
# [Info]  valid_per_epoch: 0.025373s
# [Info]  time_per_epoch: 0.389433s
# [Info]  ETA: 0m 38s
#
# ---------------------epoch 110/200----------------------
# [train] train_loss: 0.095103, train_blue: 0.989743
# [valid] valid_loss: 8.493479, valid_blue: 0.696119
# [Info]  forward_per_epoch: 0.075561s
# [Info]  backward_per_epoch: 0.221692s
# [Info]  valid_per_epoch: 0.025094s
# [Info]  time_per_epoch: 0.392959s
# [Info]  ETA: 0m 35s
#
# ---------------------epoch 120/200----------------------
# [train] train_loss: 0.072442, train_blue: 0.996460
# [valid] valid_loss: 8.348140, valid_blue: 0.696119
# [Info]  forward_per_epoch: 0.071650s
# [Info]  backward_per_epoch: 0.213516s
# [Info]  valid_per_epoch: 0.023295s
# [Info]  time_per_epoch: 0.376048s
# [Info]  ETA: 0m 30s
#
# ---------------------epoch 130/200----------------------
# [train] train_loss: 0.055905, train_blue: 0.998060
# [valid] valid_loss: 8.508342, valid_blue: 0.696119
# [Info]  forward_per_epoch: 0.070923s
# [Info]  backward_per_epoch: 0.215636s
# [Info]  valid_per_epoch: 0.024079s
# [Info]  time_per_epoch: 0.375311s
# [Info]  ETA: 0m 26s
#
# ---------------------epoch 140/200----------------------
# [train] train_loss: 0.043739, train_blue: 1.000000
# [valid] valid_loss: 8.642677, valid_blue: 0.696119
# [Info]  forward_per_epoch: 0.068180s
# [Info]  backward_per_epoch: 0.222042s
# [Info]  valid_per_epoch: 0.025905s
# [Info]  time_per_epoch: 0.389308s
# [Info]  ETA: 0m 23s
#
# ---------------------epoch 150/200----------------------
# [train] train_loss: 0.034920, train_blue: 1.000000
# [valid] valid_loss: 8.756521, valid_blue: 0.696119
# [Info]  forward_per_epoch: 0.071534s
# [Info]  backward_per_epoch: 0.217695s
# [Info]  valid_per_epoch: 0.023473s
# [Info]  time_per_epoch: 0.376519s
# [Info]  ETA: 0m 18s
#
# ---------------------epoch 160/200----------------------
# [train] train_loss: 0.028494, train_blue: 1.000000
# [valid] valid_loss: 8.868189, valid_blue: 0.696119
# [Info]  forward_per_epoch: 0.069639s
# [Info]  backward_per_epoch: 0.212936s
# [Info]  valid_per_epoch: 0.024247s
# [Info]  time_per_epoch: 0.371478s
# [Info]  ETA: 0m 14s
#
# ---------------------epoch 170/200----------------------
# [train] train_loss: 0.023650, train_blue: 1.000000
# [valid] valid_loss: 8.974234, valid_blue: 0.696119
# [Info]  forward_per_epoch: 0.071033s
# [Info]  backward_per_epoch: 0.220455s
# [Info]  valid_per_epoch: 0.024213s
# [Info]  time_per_epoch: 0.380529s
# [Info]  ETA: 0m 11s
#
# ---------------------epoch 180/200----------------------
# [train] train_loss: 0.019899, train_blue: 1.000000
# [valid] valid_loss: 9.073956, valid_blue: 0.696119
# [Info]  forward_per_epoch: 0.071894s
# [Info]  backward_per_epoch: 0.217904s
# [Info]  valid_per_epoch: 0.024339s
# [Info]  time_per_epoch: 0.382481s
# [Info]  ETA: 0m 7s
#
# ---------------------epoch 190/200----------------------
# [train] train_loss: 0.016930, train_blue: 1.000000
# [valid] valid_loss: 9.168703, valid_blue: 0.696119
# [Info]  forward_per_epoch: 0.068482s
# [Info]  backward_per_epoch: 0.210867s
# [Info]  valid_per_epoch: 0.023552s
# [Info]  time_per_epoch: 0.365586s
# [Info]  ETA: 0m 3s
#
# ---------------------epoch 200/200----------------------
# [train] train_loss: 0.014536, train_blue: 1.000000
# [valid] valid_loss: 9.259420, valid_blue: 0.696119
# [Info]  forward_per_epoch: 0.071463s
# [Info]  backward_per_epoch: 0.212120s
# [Info]  valid_per_epoch: 0.024903s
# [Info]  time_per_epoch: 0.376504s
# [Info]  ETA: 0m 0s

# %%
# plot the result
fig = plt.gcf()
fig.set_size_inches(16,10)
for i in range(2):
    plt.subplot(2, 2, i * 2 + 1)
    plt.plot(range(epoch), [train_log[i][j]["train_loss"] for j in range(epoch)], label="train_loss")
    plt.plot(range(epoch), [train_log[i][j]["valid_loss"] for j in range(epoch)], label="valid_loss")
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.xticks(range(0, epoch + 1, math.floor(epoch / 10)))
    plt.legend()
    plt.subplot(2, 2, i * 2 + 2)
    plt.plot(range(epoch), [np.mean(train_log[i][j]["train_blue"]) for j in range(epoch)], "C3", label="train_blue")
    plt.plot(range(epoch), [np.mean(train_log[i][j]["valid_blue"]) for j in range(epoch)], "C4", label="valid_blue")
    plt.xlabel('epoch')
    plt.ylabel('BLEU')
    plt.xticks(range(0, epoch + 1, math.floor(epoch / 10)))
    plt.legend()
    
plt.show()

# %%
###################################################################
#                                                                 #
#                                                                 #
#       caption generating via encoder-decoder pipeline           #
#                                                                 #
#                                                                 #
###################################################################

# initialize the pipeline
encoder_path = "models/encoder_jupyter_3d_ts32_bs200_vocal176.pth"
decoder_path = "models/decoder_jupyter_3d_ts32_bs200_vocal176.pth"
encoder_decoder = EncoderDecoder(encoder_path, decoder_path)
dataset = datasets[1]

# prepare the dataloader
train_ds = ShapeCaptionDataset(
        root, 
        dataset.transformed_data['train'],
        mode="hdf5", 
    )
train_dl = DataLoader(train_ds, batch_size=1)
valid_ds = ShapeCaptionDataset(
        root, 
        dataset.transformed_data['test'],
        mode="hdf5", 
        database="/mnt/raid/davech2y/ShapeNetCore_vol/nrrd_256_filter_div_32_solid.hdf5"
    )
valid_dl = DataLoader(valid_ds, batch_size=1)
dataloader = {
    'train': train_dl,
    'test': valid_dl
}

# caption shapes
descriptions = {
    'train': [],
    'test': []
}
images = {
    'train': [],
    'test': []
}
for phase in ["train", "test"]:
    for i, (_, visual_inputs, caps, cap_lengths) in enumerate(dataloader[phase]):
        shape_inputs = Variable(visual_inputs[1]).cuda()
        descriptions[phase] += encoder_decoder.generate_text(shape_inputs, dataset.dict_idx2word, 50)
        images[phase].append(visual_inputs[0][0])
        
    # edit the descriptions
    for i in range(len(descriptions[phase])):
        text = descriptions[phase][i].split(" ")
        new = []
        count = 0
        for j in range(len(text)):
            new.append(text[j])
            count += 1
            if count == 12:
                new.append("\n")
                count = 0
        descriptions[phase][i] = " ".join(new)

# %%
fig = plt.gcf()
fig.set_size_inches(8,4 * len(descriptions['train']))
fig.set_facecolor('white')
for i in range(len(descriptions['train'])):
    plt.subplot(len(descriptions['train']), 1, i+1)
    plt.imshow(Image.open(images['train'][i]).resize((64, 64)))
    plt.text(80, 32, descriptions['train'][i], fontsize=14)
plt.show()

# %%
fig = plt.gcf()
fig.set_size_inches(8,4 * len(descriptions['test']))
fig.set_facecolor('white')
for i in range(len(descriptions['test'])):
    plt.subplot(len(descriptions['test']), 1, i+1)
    plt.imshow(Image.open(images['test'][i]).resize((64, 64)))
    plt.text(80, 32, descriptions['test'][i], fontsize=14)
plt.show()
